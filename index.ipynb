# %% [markdown]
# # Building a Simple GIS with Yelp API and Folium - Lab
#
# ## Introduction
#
# So we have learned quite a bit about APIs and how they are now big buzzword in the tech industry. Think of it as a protocol for how to make requests and communicate with another server. We have seen how to mine Twitter for getting text data and apply basic frequency based NLP techniques to get some insight.
#
# One of the key aspects of being a data scientist is the ability to learn how a new API works, how to go through its specific authentication process (OAuth) and how to process the data structures that get returned as a response to our requests. It is a good practice to spend some time learning the API through the official documentation before sending in requests.
#
# On these lines, this lab requires you to learn another popular API (YELP Fusion) by following the provided detailed online documentation. We shall build a simple Geographical Information System (GIS) using the data from yelp.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Successfully sign up for Yelp API
# * Create HTTP requests to get data from Yelp API
# * Parse HTTP responses and perform data analysis on the data returned
# * Create a simple geographical system on to view information about selected businesses, at a given location.

# %% [markdown]
# ## The Yelp Fusion API - v3
#
#
# ### Point your browser over to this [yelp page](https://www.yelp.com/developers/v3/manage_app) and create an app in order to obtain  `client_id` and `api_key` tokens.
#
# **NOTE:** You will be required to sign up using Google or Facebook etc. if you dont already have an account.
#
# <img src="yelp_app.png" width=500>

# %% [markdown]
# After registration, you'll be presented with your account information and limits of your access. For Yelp, or any other API for that reason, you need to make sure that you dont surpass your request quota, otherwise, you may end up getting banned in some cases. Yelp shows this information to you as below:
#
# <img src="quota.png" width=500>

# %% [markdown]
# ### Save your api_key and client_id in the variables below:

# %%
import json
f = open('access_tokens.json', 'r')
tokens = json.load(f)
section_tokens = tokens['yelp']['first_yelp_app_rwilleyii']
section_tokens
# Out:
# {'Client ID': 'TKz2edtltxgYtPzgSrH9EQ',
#  'API Key': 'qq1PcXKKTinFQw_76grZ8OaSaWWPs-oN7AOcEhgUJU2ZsYyzllZF3-SoFcJ3zyeS7SbfGg3XTVDBCtUriAq7Nl_A0ZOZPbF-E5J9is5rpAwfi5HHpiWdCdA03IFGXHYx'}

# %%
# Save your tokens in the following string variables
client_id = section_tokens['Client ID']
api_key = section_tokens['API Key']

# %% [markdown]
# ## The `yelpapi`

# %% [markdown]
# The yelpapi is a pure Python implementation of the Yelp Fusion API (aka Yelp v3 API). It is simple, fast, and robust to any changes Yelp may make to the API in the future. See tha basic usage of this library on the [official Github repo](https://github.com/gfairchild/yelpapi). You may look out for other APIs to achieve this but for this lesson, we shall use it for sake of simplicity.
#
# First you must pip install the library

# %%
# !pip install yelpapi

# %% [markdown]
# ### Import `yelpapi ` into working environment and pass in the api_key as shown in the Github Repo

# %%
# Code here
from yelpapi import YelpAPI
yelp_api = YelpAPI(api_key)

# %% [markdown]
# ### The Api request and response
#
# Great so we can now start making API calls using the format:
# ```python
# response = yelp_api.search_query(term =<search term>,
#                                  location=<search location>,
#                                  sort_by='rating',
#                                  limit=50)
# ```
# We can pass in a lot more arguments to refine our search. [Here is a complete list of options that search API provides us](https://www.yelp.com/developers/documentation/v3/business_search)
#
# * Make an API request using a simple criteria location and term
# * save the response as `response`
# * inspect the type and contents of `response`.

# %%
## Pass in a spcific term and location to make a call. 
response = yelp_api.search_query(term = 'bars',
                                location = '11101',
                                sort_by = 'rating',
                                limit = 50)
# For this example, we are looking for chinese food in London.

# term = 'Chinese food'
# location = 'London'

# %%
response
# Out:
# {'businesses': [{'id': '_7-wGQfXNgbr-WDIMzUvZw',
#    'alias': 'the-moonlight-mile-brooklyn',
#    'name': 'The Moonlight Mile',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ycVKPXm-pyIwhXBaBaRIqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-moonlight-mile-brooklyn?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 65,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'whiskeybars', 'title': 'Whiskey Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7321141, 'longitude': -73.9578424},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '200 Franklin St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 Franklin St', 'Brooklyn, NY 11222']},
#    'phone': '+17183893904',
#    'display_phone': '(718) 389-3904',
#    'distance': 2325.659639633939},
#   {'id': 'NpK70BQzYRGO3h340YvRuA',
#    'alias': 'bierwax-brooklyn-3',
#    'name': 'BierWax',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vdDk4ipmIK_vbviD99ysSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bierwax-brooklyn-3?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 48,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.6800201748959,
#     'longitude': -73.9682761207223},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '556 Vanderbilt Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['556 Vanderbilt Ave', 'Brooklyn, NY 11238']},
#    'phone': '+13475338449',
#    'display_phone': '(347) 533-8449',
#    'distance': 7729.6868840777515},
#   {'id': 'ZvR85HJOsZa-CTn7rabhjw',
#    'alias': 'solid-state-woodside',
#    'name': 'Solid State',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ACnMGMCyGoSn4K6BtqowjQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/solid-state-woodside?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 54,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.744532, 'longitude': -73.91082},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '53-22 Roosevelt Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['53-22 Roosevelt Ave', 'Woodside, NY 11377']},
#    'phone': '+13479353042',
#    'display_phone': '(347) 935-3042',
#    'distance': 2145.299402368407},
#   {'id': 'kEC66zgpguVsizQeCAJoCg',
#    'alias': 'blacktail-new-york',
#    'name': 'BlackTail',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lfDVZ939qlnB9cWjkcFSGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blacktail-new-york?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 231,
#    'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7044769199104,
#     'longitude': -74.0174372308775},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '22 Battery Pl',
#     'address2': None,
#     'address3': 'Fl 2 Pier A',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['22 Battery Pl', 'Fl 2 Pier A', 'New York, NY 10004']},
#    'phone': '+12127850153',
#    'display_phone': '(212) 785-0153',
#    'distance': 8200.685688332946},
#   {'id': 'Sj3JYCbaEFrAqUzRrenQbg',
#    'alias': 'jora-restaurant-and-bar-long-island-city',
#    'name': 'Jora Restaurant & Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Fzckhw-nQGKVyBUKmsIfMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jora-restaurant-and-bar-long-island-city?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 466,
#    'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7438054, 'longitude': -73.9515007},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '47-46 11th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47-46 11th St', 'Long Island City, NY 11101']},
#    'phone': '+17183922033',
#    'display_phone': '(718) 392-2033',
#    'distance': 1291.8313611569017},
#   {'id': 'O7CnII31QnhLIYoUlOXrZA',
#    'alias': 'la-sala-astoria',
#    'name': 'La Sala',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DZKzPRQZV-q1P6PXKFvaaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-sala-astoria?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 101,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7632006, 'longitude': -73.9286183},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3205 Crescent St',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3205 Crescent St', 'Astoria, NY 11106']},
#    'phone': '+17186066121',
#    'display_phone': '(718) 606-6121',
#    'distance': 2106.5646225291975},
#   {'id': 'Ra4ZUUvSlGL7u1vNBhNPPQ',
#    'alias': 'bantry-bay-publick-house-long-island-city-2',
#    'name': 'Bantry Bay Publick House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1N7_lVLgKRKxCj-fcOkFfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bantry-bay-publick-house-long-island-city-2?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 85,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'irish', 'title': 'Irish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73581, 'longitude': -73.9346599},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3301 Greenpoint Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3301 Greenpoint Ave', 'Long Island City, NY 11101']},
#    'phone': '+17187849500',
#    'display_phone': '(718) 784-9500',
#    'distance': 1061.3442144815322},
#   {'id': 'YgQ1AVY9JLSMjSRX3Hzj1g',
#    'alias': 'lic-market-long-island-city',
#    'name': 'LIC Market',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8V3qY0djSWCSjfnKD5asFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lic-market-long-island-city?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 724,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74745, 'longitude': -73.94552},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '21-52 44th Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['21-52 44th Dr', 'Long Island City, NY 11101']},
#    'phone': '+17183610013',
#    'display_phone': '(718) 361-0013',
#    'distance': 817.0955882238269},
#   {'id': '6u-4kVhNhpXuRjTO426eag',
#    'alias': 'fifth-hammer-brewing-long-island-city-2',
#    'name': 'Fifth Hammer Brewing',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UT7wg4gnP-4HRwFRXJe51A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fifth-hammer-brewing-long-island-city-2?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 73,
#    'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74641, 'longitude': -73.95153},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '10-28 46th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10-28 46th Ave', 'Long Island City, NY 11101']},
#    'phone': '+17186632084',
#    'display_phone': '(718) 663-2084',
#    'distance': 1293.6525037328568},
#   {'id': '2ImxE13EzjWAtDXQfIU68Q',
#    'alias': 'sutton-bar-room-new-york',
#    'name': 'Sutton Bar Room',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0yPn4hnPSDNU3dFT-9WqmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sutton-bar-room-new-york?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 40,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75921, 'longitude': -73.96205},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1074 1st Avenue',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1074 1st Avenue', 'New York, NY 10022']},
#    'phone': '+12129809850',
#    'display_phone': '(212) 980-9850',
#    'distance': 2664.5005866846823},
#   {'id': 'D9JaKH-Y_LVOjRSAdbmyyA',
#    'alias': 'big-alice-brewing-long-island-city',
#    'name': 'Big aLICe Brewing',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_Nmc7pYZweCKIvHdbrE80g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/big-alice-brewing-long-island-city?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 96,
#    'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7520775, 'longitude': -73.9505905},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '8-08 43rd Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8-08 43rd Rd', 'Long Island City, NY 11101']},
#    'phone': '+13476882337',
#    'display_phone': '(347) 688-2337',
#    'distance': 1430.308272127699},
#   {'id': 'RemvTpxalDjSew5HwmNzUQ',
#    'alias': 'the-dead-rabbit-new-york',
#    'name': 'The Dead Rabbit',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_4T5R0HHhASROheby-TXDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dead-rabbit-new-york?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 1367,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70329, 'longitude': -74.01102},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '30 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['30 Water St', 'New York, NY 10004']},
#    'phone': '+16464227906',
#    'display_phone': '(646) 422-7906',
#    'distance': 7833.693312591311},
#   {'id': 'NVp1S29NLR573Lc4ZvICKw',
#    'alias': 'forest-hills-station-house-forest-hills',
#    'name': 'Forest Hills Station House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pxgmrET-6EaeJpqLzbHAtQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/forest-hills-station-house-forest-hills?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 977,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7197971911827,
#     'longitude': -73.8451440959871},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '106-11 71st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['106-11 71st Ave', 'Forest Hills, NY 11375']},
#    'phone': '+17185445000',
#    'display_phone': '(718) 544-5000',
#    'distance': 8180.083599741669},
#   {'id': 'k5bGHJbAXDw9g_uP42QqDw',
#    'alias': 'the-highwater-astoria',
#    'name': 'The Highwater',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Dgc_AfvjoM-gH7vWW3iUvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-highwater-astoria?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 210,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'hawaiian', 'title': 'Hawaiian'},
#     {'alias': 'tikibars', 'title': 'Tiki Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76033, 'longitude': -73.92245},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '34-20 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['34-20 Broadway', 'Astoria, NY 11106']},
#    'phone': '+19177450407',
#    'display_phone': '(917) 745-0407',
#    'distance': 2053.834972904262},
#   {'id': 'VP4ITyWN639nGSLM9NRdEw',
#    'alias': 'rockaway-brewing-company-long-island-city',
#    'name': 'Rockaway Brewing Company',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MiAdXkufXSnCY8M5AgTejg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rockaway-brewing-company-long-island-city?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 165,
#    'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7470981842068,
#     'longitude': -73.9549534404755},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '46-01 5th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['46-01 5th St', 'Long Island City, NY 11101']},
#    'phone': '+17184826528',
#    'display_phone': '(718) 482-6528',
#    'distance': 1588.4107561675814},
#   {'id': 'iigqtLntqUS18cXmEXofIQ',
#    'alias': 'the-lowery-bar-and-kitchen-sunnyside',
#    'name': 'The Lowery Bar & Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zr0AgCXeSuZh0yKAvz2oAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-lowery-bar-and-kitchen-sunnyside?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 196,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7451454550028,
#     'longitude': -73.9208489656448},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '43-02 43rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Sunnyside',
#     'zip_code': '11104',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43-02 43rd Ave', 'Sunnyside, NY 11104']},
#    'phone': '+19292080054',
#    'display_phone': '(929) 208-0054',
#    'distance': 1286.8786006775372},
#   {'id': '3lLBRLbXAIgd1yZgWgnfeg',
#    'alias': 'dutch-kills-long-island-city',
#    'name': 'Dutch Kills',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/I4paO44YkfkRmeABU4TsCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dutch-kills-long-island-city?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 706,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.747615, 'longitude': -73.940159},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '27-24 Jackson Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['27-24 Jackson Ave', 'Long Island City, NY 11101']},
#    'phone': '+17183832724',
#    'display_phone': '(718) 383-2724',
#    'distance': 426.0003366258881},
#   {'id': 'UF9F0A4e7AJHzNPG5zrHUQ',
#    'alias': 'the-beast-next-door-long-island-city',
#    'name': 'The Beast Next Door',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5AJudcMfoPYd9VQ3H7dkiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-beast-next-door-long-island-city?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 157,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74881, 'longitude': -73.94073},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '42-51 27th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42-51 27th St', 'Long Island City, NY 11101']},
#    'phone': '+17184827507',
#    'display_phone': '(718) 482-7507',
#    'distance': 555.1693255245904},
#   {'id': 'UJSQHmL81lgWqBrc9Bp3Cw',
#    'alias': 'maggie-maes-sunnyside',
#    'name': "Maggie Mae's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JuehgrTG4KDgckhsZgJRDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maggie-maes-sunnyside?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 117,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7438348, 'longitude': -73.9230293},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '41-15 Queens Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Sunnyside',
#     'zip_code': '11104',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41-15 Queens Blvd', 'Sunnyside, NY 11104']},
#    'phone': '+17184333067',
#    'display_phone': '(718) 433-3067',
#    'distance': 1125.3515304625234},
#   {'id': 'wmDx6a6HPvlq5lX3wH52EA',
#    'alias': 'saint-vitus-brooklyn',
#    'name': 'Saint Vitus',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8LKt4SueFsmlvATqxAwnMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saint-vitus-brooklyn?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 132,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73678, 'longitude': -73.95517},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1120 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1120 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1847.5066022500791},
#   {'id': 'EKk-W0musmo4z1qnQQ5XgA',
#    'alias': 'the-local-bar-and-cafe-long-island-city',
#    'name': 'The Local Bar and Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8fhr5P7uE-EzVYtXi35mfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-local-bar-and-cafe-long-island-city?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 66,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7495622, 'longitude': -73.9477008},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '13-02 44th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['13-02 44th Ave', 'Long Island City, NY 11101']},
#    'phone': '+13477385251',
#    'display_phone': '(347) 738-5251',
#    'distance': 1079.8522355390298},
#   {'id': '9jceg0585cKrwBLarT9ftQ',
#    'alias': 'our-wicked-lady-brooklyn',
#    'name': 'Our Wicked Lady',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hPBflgP1lnCH-Uw5RL8LfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/our-wicked-lady-brooklyn?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 57,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.709384, 'longitude': -73.93333},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '153 Morgan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['153 Morgan Ave', 'Brooklyn, NY 11237']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3987.8788172309373},
#   {'id': '6BDNKIOtJ3dFLRvXE_4NSQ',
#    'alias': 'anable-basin-sailing-bar-and-grill-long-island-city',
#    'name': 'Anable Basin Sailing Bar & Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/t6FSsONtfRyH9MhnybaJhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anable-basin-sailing-bar-and-grill-long-island-city?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 145,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.749385, 'longitude': -73.9550896},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4-40 44th Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4-40 44th Dr', 'Long Island City, NY 11101']},
#    'phone': '+16462071333',
#    'display_phone': '(646) 207-1333',
#    'distance': 1666.1848257866598},
#   {'id': 'MvLCuHIcEPvZ12RZdsSckA',
#    'alias': 'domaine-wine-bar-long-island-city',
#    'name': 'Domaine Wine Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dr2alRWPj7EPPVTLFW178A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/domaine-wine-bar-long-island-city?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 125,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'jazzandblues', 'title': 'Jazz & Blues'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7425913214684,
#     'longitude': -73.9542330801487},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '50-04 Vernon Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['50-04 Vernon Blvd', 'Long Island City, NY 11101']},
#    'phone': '+17187842350',
#    'display_phone': '(718) 784-2350',
#    'distance': 1548.8214628511723},
#   {'id': 'p6-X_mg5ETcUuV-X4RkPCg',
#    'alias': 'citroën-brooklyn',
#    'name': 'Citroën',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JxB9EP6Lc-9vKx_WZGwsmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/citro%C3%ABn-brooklyn?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 22,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7312, 'longitude': -73.95459},
#    'transactions': ['restaurant_reservation'],
#    'location': {'address1': '931 Manhattan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['931 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17187342220',
#    'display_phone': '(718) 734-2220',
#    'distance': 2197.3037866245672},
#   {'id': 'wGIYs_qHA4Haiys7ruADeA',
#    'alias': 'existing-conditions-new-york-2',
#    'name': 'Existing Conditions',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EuX0RZyd49dMDeKV3Du6WA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/existing-conditions-new-york-2?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 36,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7331938777287,
#     'longitude': -73.9980158968661},
#    'transactions': [],
#    'location': {'address1': '35 W 8th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35 W 8th St', 'New York, NY 10011']},
#    'phone': '+12122038935',
#    'display_phone': '(212) 203-8935',
#    'distance': 5369.612721615905},
#   {'id': 'jW22gmsZjh5hFJsC1qUDOA',
#    'alias': 'the-baroness-bar-kitchen-long-island-city-2',
#    'name': 'The Baroness Bar + Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XyEPNrK9G2Y2223zbtjlfw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-baroness-bar-kitchen-long-island-city-2?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 324,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.751697, 'longitude': -73.939941},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '41-26 Crescent St',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41-26 Crescent St', 'Long Island City, NY 11101']},
#    'phone': '+17187845065',
#    'display_phone': '(718) 784-5065',
#    'distance': 790.4314466361154},
#   {'id': 'RhtO1FSefPfqpojBAwuEWw',
#    'alias': 'transmitter-brewing-long-island-city',
#    'name': 'Transmitter Brewing',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aCnq1X7kxlOglEP4TmePSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/transmitter-brewing-long-island-city?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 73,
#    'categories': [{'alias': 'breweries', 'title': 'Breweries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7402434, 'longitude': -73.9527181},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '53-02 11th St',
#     'address2': 'Ste A',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['53-02 11th St',
#      'Ste A',
#      'Long Island City, NY 11101']},
#    'phone': '+16463788529',
#    'display_phone': '(646) 378-8529',
#    'distance': 1489.7025174856024},
#   {'id': 'AydiQxXWQLqVrZ9sEZTxtw',
#    'alias': 'the-ship-new-york',
#    'name': 'The Ship',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/h1nZSOv6yDb6UJfst3bZ0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ship-new-york?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 296,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7198443, 'longitude': -73.99947},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '158 Lafayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['158 Lafayette St', 'New York, NY 10013']},
#    'phone': '+12122198496',
#    'display_phone': '(212) 219-8496',
#    'distance': 6023.557066881809},
#   {'id': 'PcF_ebeELn7mg6vqVnHjIg',
#    'alias': 'elsa-brooklyn',
#    'name': 'Elsa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KAhWiV26AcjK7WMnDdExgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/elsa-brooklyn?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 74,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69027, 'longitude': -73.99535},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '136 Atlantic Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['136 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+19178827395',
#    'display_phone': '(917) 882-7395',
#    'distance': 7879.38140654683},
#   {'id': 'bQraKjILxZGN1GNKt5XUKA',
#    'alias': 'ramona-brooklyn',
#    'name': 'Ramona',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/273-Jlv14mNN1p5UWRXrGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ramona-brooklyn?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 114,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7302444236037,
#     'longitude': -73.9578210900354},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '113 Franklin St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['113 Franklin St', 'Brooklyn, NY 11222']},
#    'phone': '+13472278164',
#    'display_phone': '(347) 227-8164',
#    'distance': 2459.445215704108},
#   {'id': '_97KwnwjUHwSVWs-XrlFcg',
#    'alias': 'the-astorian-astoria',
#    'name': 'The Astorian',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rnN0eWVx3Ev2RYkG9nl2XA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-astorian-astoria?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 101,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76739, 'longitude': -73.92136},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '28-50 31st St',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28-50 31st St', 'Astoria, NY 11102']},
#    'phone': '+19177451179',
#    'display_phone': '(917) 745-1179',
#    'distance': 2774.0545932470177},
#   {'id': 'ZgU1Jmw9Itx_bEveDXtiFA',
#    'alias': 'jacksons-eatery-bar-long-island-city-2',
#    'name': "Jackson's Eatery | Bar",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5slF0kRjDLksk51ila2lJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jacksons-eatery-bar-long-island-city-2?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 168,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74241, 'longitude': -73.95323},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '10-37 Jackson Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10-37 Jackson Ave', 'Long Island City, NY 11101']},
#    'phone': '+13476491721',
#    'display_phone': '(347) 649-1721',
#    'distance': 1463.8890297610317},
#   {'id': 'Qg3J6XPrD22CEFAqEEhWpw',
#    'alias': 'the-pony-bar-new-york-2',
#    'name': 'The Pony Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YW1OrgkI64KUwIdXRmLiog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pony-bar-new-york-2?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 339,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76974, 'longitude': -73.95425},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1444 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1444 1st Ave', 'New York, NY 10021']},
#    'phone': '+12122880090',
#    'display_phone': '(212) 288-0090',
#    'distance': 3123.7047384202056},
#   {'id': 'GktRnSCBAsboHj9Hh-U66g',
#    'alias': 'greca-new-york-3',
#    'name': 'GRECA',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/E8HJ-2xewlhT5a_MRMfe1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/greca-new-york-3?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 31,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7239479, 'longitude': -74.010406},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '452 Washington St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['452 Washington St', 'New York, NY 10013']},
#    'phone': '+19172614795',
#    'display_phone': '(917) 261-4795',
#    'distance': 6677.586441563152},
#   {'id': 'BfhICClikxU7AG01nOOeCA',
#    'alias': 'prospect-brooklyn',
#    'name': 'Prospect',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/z6FToGDEZNaMGc6cWDV41g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prospect-brooklyn?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 224,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68619, 'longitude': -73.97377},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '773 Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['773 Fulton St', 'Brooklyn, NY 11217']},
#    'phone': '+17185966826',
#    'display_phone': '(718) 596-6826',
#    'distance': 7276.229601929284},
#   {'id': 'KqxBfDaww1j0qhgDGh-VSg',
#    'alias': 'diamond-dogs-astoria',
#    'name': 'Diamond Dogs',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cp5C_NMqJEcof79o6fb7sw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/diamond-dogs-astoria?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 119,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'beergardens', 'title': 'Beer Gardens'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76285, 'longitude': -73.92099},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '34-04 31st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['34-04 31st Ave', 'Astoria, NY 11106']},
#    'phone': '+19295220061',
#    'display_phone': '(929) 522-0061',
#    'distance': 2374.6062293441646},
#   {'id': 'NVx7gfdd4NDAwvj6URZ2aQ',
#    'alias': 'a-roof-bar-flushing',
#    'name': 'A+ Roof Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZkP7XZhNXOL3Jz4Kw_1xUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/a-roof-bar-flushing?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 76,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7584693, 'longitude': -73.834706},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'The Parc Hotel',
#     'address2': '',
#     'address3': '3916 College Point Blvd, R Level',
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['The Parc Hotel',
#      '3916 College Point Blvd, R Level',
#      'Flushing, NY 11354']},
#    'phone': '+17188691691',
#    'display_phone': '(718) 869-1691',
#    'distance': 8682.349956202024},
#   {'id': 'JboVlCv3LtJt8hA-yI9U0A',
#    'alias': 'beija-flor-long-island-city',
#    'name': 'Beija Flor',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CWF3S-pHtYOIItaECnUnZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beija-flor-long-island-city?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 192,
#    'categories': [{'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.754601940029,
#     'longitude': -73.9336216385827},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '38-02 29th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['38-02 29th St', 'Long Island City, NY 11101']},
#    'phone': '+17186062468',
#    'display_phone': '(718) 606-2468',
#    'distance': 1072.8548080593755},
#   {'id': 'mIDV-IEfeZsQtVW1BUHXLA',
#    'alias': 'indie-long-island-city',
#    'name': 'Indie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/E9dCVt1aswKTEamqig8K_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/indie-long-island-city?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 66,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7488489690995,
#     'longitude': -73.942321872803},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '43-10 Crescent St',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43-10 Crescent St', 'Long Island City, NY 11101']},
#    'phone': '+17184826954',
#    'display_phone': '(718) 482-6954',
#    'distance': 653.9125160682504},
#   {'id': '968r2kMB3ZWkyZxOm4XoRw',
#    'alias': 'copper-kettle-bar-and-restaurant-woodside-2',
#    'name': 'Copper Kettle Bar & Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TE80fU5Jdm-hsL58qE_QCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/copper-kettle-bar-and-restaurant-woodside-2?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 139,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'irish', 'title': 'Irish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7460850008934,
#     'longitude': -73.9138449996237},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '5024 Skillman Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5024 Skillman Ave', 'Woodside, NY 11377']},
#    'phone': '+17183357596',
#    'display_phone': '(718) 335-7596',
#    'distance': 1914.752275969023},
#   {'id': 'WfJNUmeFNU8_fznPgY9N_g',
#    'alias': 'idas-nearabout-sunnyside',
#    'name': "Ida's Nearabout",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9VUAE0n8KWlx8B9jBNBe0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/idas-nearabout-sunnyside?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 81,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7437641, 'longitude': -73.9208344},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '43-13 Queens Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Sunnyside',
#     'zip_code': '11104',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43-13 Queens Blvd', 'Sunnyside, NY 11104']},
#    'phone': '+17184331916',
#    'display_phone': '(718) 433-1916',
#    'distance': 1309.7935898757287},
#   {'id': 'xrvy5KXhBdFL9UJz1kto6A',
#    'alias': 'lic-beer-project-long-island-city',
#    'name': 'LIC Beer Project',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rum_G8D1H8Om3IZNCxtLQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lic-beer-project-long-island-city?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 98,
#    'categories': [{'alias': 'breweries', 'title': 'Breweries'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7548729, 'longitude': -73.939375},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '39-28 23rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39-28 23rd St', 'Long Island City, NY 11101']},
#    'phone': '+19178326840',
#    'display_phone': '(917) 832-6840',
#    'distance': 1110.7048105422928},
#   {'id': 'AYBRN8pKB8_ZfcCks17OmQ',
#    'alias': 'beebes-long-island-city',
#    'name': "Beebe's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iEToVluuxHpqfU-PXUN0UA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beebes-long-island-city?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 50,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7547438, 'longitude': -73.9358372},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '38-28 27th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['38-28 27th St', 'Long Island City, NY 11101']},
#    'phone': '+17182082895',
#    'display_phone': '(718) 208-2895',
#    'distance': 1074.2910399963962},
#   {'id': 'sfI6z7L1AGuz6Ml_pf7BIQ',
#    'alias': 'do-or-dive-brooklyn',
#    'name': 'Do or Dive',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yb8Cc-eEXCMBblDh0_pqUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/do-or-dive-brooklyn?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 50,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6867587, 'longitude': -73.9548362},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1108 Bedford Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1108 Bedford Ave', 'Brooklyn, NY 11216']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6680.256888707099},
#   {'id': 'xn0g_LqMcVACrWuox5GF1g',
#    'alias': 'dominies-hoek-long-island-city',
#    'name': "Dominie's Hoek",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mgBQrQ9cXTI1bheAVJTxig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dominies-hoek-long-island-city?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 254,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.743536, 'longitude': -73.953545},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4817 Vernon Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4817 Vernon Blvd', 'Long Island City, NY 11101']},
#    'phone': '+17187066531',
#    'display_phone': '(718) 706-6531',
#    'distance': 1469.4903028534652},
#   {'id': '-WUCua_aSIpfsHKMFlMEMg',
#    'alias': 'dirty-precious-brooklyn',
#    'name': 'Dirty Precious',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NJDSQRaaLc3dTwDHZPXPvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dirty-precious-brooklyn?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 63,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6763896691334,
#     'longitude': -73.9867169468351},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '317 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['317 3rd Ave', 'Brooklyn, NY 11215']},
#    'phone': '+16466854481',
#    'display_phone': '(646) 685-4481',
#    'distance': 8749.946801777218},
#   {'id': 'N-sbhyxuugMun5_mPovqPg',
#    'alias': 'mad-donkey-beer-bar-and-grill-astoria',
#    'name': 'Mad Donkey Beer Bar & Grill',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1M7ZLvm2dQAOhJv9lw3VSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mad-donkey-beer-bar-and-grill-astoria?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 328,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.756262, 'longitude': -73.928487},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '3207 36th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3207 36th Ave', 'Astoria, NY 11106']},
#    'phone': '+17182042070',
#    'display_phone': '(718) 204-2070',
#    'distance': 1391.798324785981},
#   {'id': 'HV8xairb2qct7wSHqNwqXw',
#    'alias': 'levante-long-island-city',
#    'name': 'Levante',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/O4TRDmRCkwnd1nyw27m1AQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/levante-long-island-city?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 151,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7476399, 'longitude': -73.94173},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '26-21 Jackson Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26-21 Jackson Ave', 'Long Island City, NY 11101']},
#    'phone': '+17183923885',
#    'display_phone': '(718) 392-3885',
#    'distance': 537.2003417867887},
#   {'id': 'Pn5B8A4P23d5_FE6y8A2wA',
#    'alias': 'mama-fox-brooklyn',
#    'name': 'Mama Fox',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gnRcp55qLcO1tsdCHPjtJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mama-fox-brooklyn?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    'review_count': 49,
#    'categories': [{'alias': 'tradamerican',
#      'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6832286325504,
#     'longitude': -73.9319809048272},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '327 Stuyvesant Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11233',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['327 Stuyvesant Ave', 'Brooklyn, NY 11233']},
#    'phone': '+13476634535',
#    'display_phone': '(347) 663-4535',
#    'distance': 6896.455519142848}],
#  'total': 3900,
#  'region': {'center': {'longitude': -73.93627166748047,
#    'latitude': 40.745164685533226}}}

# %%
# Make an API call using chosen term and location

response = yelp_api.search_query(term = 'Chinese food',
                                location = 'London',
                                sort_by = 'rating',
                                limit = 50)
print(type(response))
print(response)
# Out:
# <class 'dict'>
# {'businesses': [{'id': 'h2cCoDNQOPd51HFwvuAGNg', 'alias': 'hakkasan-london-3', 'name': 'Hakkasan', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IcS9yzJnweDO4DsfJ94jAw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/hakkasan-london-3?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ', 'review_count': 219, 'categories': [{'alias': 'cantonese', 'title': 'Cantonese'}], 'rating': 4.0, 'coordinates': {'latitude': 51.5171482803943, 'longitude': -0.13180578932657}, 'transactions': [], 'price': '££££', 'location': {'address1': '8 Hanway Place', 'address2': '', 'address3': '', 'city': 'London', 'zip_code': 'W1T 1HD', 'country': 'GB', 'state': 'XGL', 'display_address': ['8 Hanway Place', 'London W1T 1HD', 'United Kingdom']}, 'phone': '+442079277000', 'display_phone': '+44 20 7927 7000', 'distance': 558.9650039747677}, {'id': 'QE5aa5N-dbfvafLsjn7TVg', 'alias': 'bamboo-flute-fitzrovia', 'name': 'Bamboo Flute', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kYQZjHmzt8zy1634OsAsxQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/bamboo-flute-fitzrovia?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ', 'review_count': 28, 'categories': [{'alias': 'chinese', 'title': 'Chinese'}], 'rating': 4.5, 'coordinates': {'latitude': 51.5228746, 'longitude': -0.1418939}, 'transactions': [], 'price': '£', 'location': {'address1': '145 Cleveland Street', 'address2': '', 'address3': '', 'city': 'Fitzrovia', 'zip_code': 'W1T 6QH', 'country': 'GB', 'state': 'XGL', 'display_address': ['145 Cleveland Street', 'Fitzrovia W1T 6QH', 'United Kingdom']}, 'phone': '+442073872738', 'display_phone': '+44 20 7387 2738', 'distance': 1189.5082547156321}, {'id': 'sYwBQ7mJYhB35nn-_SZstQ', 'alias': 'yauatcha-london-7', 'name': 'Yauatcha', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/G7Ydt9lmtWsUN1gRhlCRsw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/yauatcha-london-7?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ', 'review_count': 460, 'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'noodles', 'title': 'Noodles'}], 'rating': 4.0, 'coordinates': {'latitude': 51.5137076071076, 'longitude': -0.135128831605189}, 'transactions': [], 'price': '£££', 'location': {'address1': '15-17 Broadwick Street', 'address2': '', 'address3': '', 'city': 'London', 'zip_code': 'W1F 0DL', 'country': 'GB', 'state': 'XGL', 'display_address': ['15-17 Broadwick Street', 'London W1F 0DL', 'United Kingdom']}, 'phone': '+442074948888', 'display_phone': '+44 20 7494 8888', 'distance': 112.59840998419494}, {'id': 'xYYh1dd95idvwCoGZWq58g', 'alias': 'bao-soho-london', 'name': 'BAO - Soho', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/L-08d4lsRSOe2HlIs1ZmfA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/bao-soho-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ', 'review_count': 167, 'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'}], 'rating': 4.0, 'coordinates': {'latitude': 51.5132221949841, 'longitude': -0.136528484994449}, 'transactions': [], 'price': '££', 'location': {'address1': '53 Lexington Street', 'address2': '', 'address3': '', 'city': 'London', 'zip_code': 'W1F 9AS', 'country': 'GB', 'state': 'XGL', 'display_address': ['53 Lexington Street', 'London W1F 9AS', 'United Kingdom']}, 'phone': '+442030192200', 'display_phone': '+44 20 3019 2200', 'distance': 58.47355609756945}, {'id': 'pdFiFtol9YI__9ROOXUIYA', 'alias': 'lanzhou-noodle-bar-london', 'name': 'Lanzhou Noodle Bar', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OMre4TNCrkDck3wqpUXbjQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/la ...

# %% [markdown]
# ### JSON .. again !
#
# We have a nice nifty little return now! As you can see, the contents of the response is formatted as a string but what kind of data structures does this remind you of?
#
# To start there's the outer curly brackets:
#
# #### {"businesses":
#
# Hopefully you're thinking 'hey that's just like a python dictionary!'
#
# Then within that we have what appears to be a list of dictionaries:
#
# #### {"id": "jeWIYbgBho9vBDhc5S1xvg",
#
# This response is an example of a JSON (JavaScript Object Notation) format that we've seen so many times before. We can simply treat it as a dictionary and process it further.

# %% [markdown]
# ### Inspect the values for all the keys in the response

# %%
# inspect the key value pairs to understand the strcuture of data 

for key in response.keys():
    print(response[key])
# Out:
# [{'id': 'h2cCoDNQOPd51HFwvuAGNg', 'alias': 'hakkasan-london-3', 'name': 'Hakkasan', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IcS9yzJnweDO4DsfJ94jAw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/hakkasan-london-3?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ', 'review_count': 219, 'categories': [{'alias': 'cantonese', 'title': 'Cantonese'}], 'rating': 4.0, 'coordinates': {'latitude': 51.5171482803943, 'longitude': -0.13180578932657}, 'transactions': [], 'price': '££££', 'location': {'address1': '8 Hanway Place', 'address2': '', 'address3': '', 'city': 'London', 'zip_code': 'W1T 1HD', 'country': 'GB', 'state': 'XGL', 'display_address': ['8 Hanway Place', 'London W1T 1HD', 'United Kingdom']}, 'phone': '+442079277000', 'display_phone': '+44 20 7927 7000', 'distance': 558.9650039747677}, {'id': 'QE5aa5N-dbfvafLsjn7TVg', 'alias': 'bamboo-flute-fitzrovia', 'name': 'Bamboo Flute', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kYQZjHmzt8zy1634OsAsxQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/bamboo-flute-fitzrovia?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ', 'review_count': 28, 'categories': [{'alias': 'chinese', 'title': 'Chinese'}], 'rating': 4.5, 'coordinates': {'latitude': 51.5228746, 'longitude': -0.1418939}, 'transactions': [], 'price': '£', 'location': {'address1': '145 Cleveland Street', 'address2': '', 'address3': '', 'city': 'Fitzrovia', 'zip_code': 'W1T 6QH', 'country': 'GB', 'state': 'XGL', 'display_address': ['145 Cleveland Street', 'Fitzrovia W1T 6QH', 'United Kingdom']}, 'phone': '+442073872738', 'display_phone': '+44 20 7387 2738', 'distance': 1189.5082547156321}, {'id': 'sYwBQ7mJYhB35nn-_SZstQ', 'alias': 'yauatcha-london-7', 'name': 'Yauatcha', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/G7Ydt9lmtWsUN1gRhlCRsw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/yauatcha-london-7?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ', 'review_count': 460, 'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'noodles', 'title': 'Noodles'}], 'rating': 4.0, 'coordinates': {'latitude': 51.5137076071076, 'longitude': -0.135128831605189}, 'transactions': [], 'price': '£££', 'location': {'address1': '15-17 Broadwick Street', 'address2': '', 'address3': '', 'city': 'London', 'zip_code': 'W1F 0DL', 'country': 'GB', 'state': 'XGL', 'display_address': ['15-17 Broadwick Street', 'London W1F 0DL', 'United Kingdom']}, 'phone': '+442074948888', 'display_phone': '+44 20 7494 8888', 'distance': 112.59840998419494}, {'id': 'xYYh1dd95idvwCoGZWq58g', 'alias': 'bao-soho-london', 'name': 'BAO - Soho', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/L-08d4lsRSOe2HlIs1ZmfA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/bao-soho-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ', 'review_count': 167, 'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'}], 'rating': 4.0, 'coordinates': {'latitude': 51.5132221949841, 'longitude': -0.136528484994449}, 'transactions': [], 'price': '££', 'location': {'address1': '53 Lexington Street', 'address2': '', 'address3': '', 'city': 'London', 'zip_code': 'W1F 9AS', 'country': 'GB', 'state': 'XGL', 'display_address': ['53 Lexington Street', 'London W1F 9AS', 'United Kingdom']}, 'phone': '+442030192200', 'display_phone': '+44 20 3019 2200', 'distance': 58.47355609756945}, {'id': 'pdFiFtol9YI__9ROOXUIYA', 'alias': 'lanzhou-noodle-bar-london', 'name': 'Lanzhou Noodle Bar', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OMre4TNCrkDck3wqpUXbjQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/lanzhou-noodle-ba ...
# 1200
# {'center': {'longitude': -0.135955810546875, 'latitude': 51.51283552118349}}

# %% [markdown]
# Whoops, what's going on here!? Well, notice from our previous preview of the response that we saw there were a hierarhcy within the response. Let's begin to investigate further to see what the problem is.
#
# First, recall that the overall strucutre of the response was a dictionary. Let's look at what the keys are:

# %%
response.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %% [markdown]
# Consult the Yelp API and learn what value is carried in each key.
#
# #### Continue to preview these keys  further to get a little better acquainted.

# %%
print('BUSINESS:', response['businesses'][0], '\n')

print('REGION:', response['region'], '\n')

print('TOTAL :',response['total'])
# Out:
# BUSINESS: {'id': 'h2cCoDNQOPd51HFwvuAGNg', 'alias': 'hakkasan-london-3', 'name': 'Hakkasan', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/IcS9yzJnweDO4DsfJ94jAw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/hakkasan-london-3?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ', 'review_count': 219, 'categories': [{'alias': 'cantonese', 'title': 'Cantonese'}], 'rating': 4.0, 'coordinates': {'latitude': 51.5171482803943, 'longitude': -0.13180578932657}, 'transactions': [], 'price': '££££', 'location': {'address1': '8 Hanway Place', 'address2': '', 'address3': '', 'city': 'London', 'zip_code': 'W1T 1HD', 'country': 'GB', 'state': 'XGL', 'display_address': ['8 Hanway Place', 'London W1T 1HD', 'United Kingdom']}, 'phone': '+442079277000', 'display_phone': '+44 20 7927 7000', 'distance': 558.9650039747677}
#
# REGION: {'center': {'longitude': -0.135955810546875, 'latitude': 51.51283552118349}}
#
# TOTAL : 1200

# %% [markdown]
# This makes more sense, so we are mainly interested in the `businesses` for our needs.
#
# ### Print the names of businesses and included ratings

# %%
for key in response['businesses'][0].keys():
    print(key, type(response['businesses'][0][key]))
# Out:
# id <class 'str'>
# alias <class 'str'>
# name <class 'str'>
# image_url <class 'str'>
# is_closed <class 'bool'>
# url <class 'str'>
# review_count <class 'int'>
# categories <class 'list'>
# rating <class 'float'>
# coordinates <class 'dict'>
# transactions <class 'list'>
# price <class 'str'>
# location <class 'dict'>
# phone <class 'str'>
# display_phone <class 'str'>
# distance <class 'float'>

# %%
print('Total Businesses: {}\n\n'.format(len(response['businesses'])))
for business in response['businesses']:
    print('Business Name: {}\nRating: {}\n'.format(business['name'], business['rating']))
# Out:
# Total Businesses: 50
#
#
# Business Name: Hakkasan
# Rating: 4.0
#
# Business Name: Bamboo Flute
# Rating: 4.5
#
# Business Name: Yauatcha
# Rating: 4.0
#
# Business Name: BAO - Soho
# Rating: 4.0
#
# Business Name: Lanzhou Noodle Bar
# Rating: 4.0
#
# Business Name: Hakkasan Mayfair
# Rating: 4.0
#
# Business Name: Silk Road
# Rating: 4.5
#
# Business Name: Hunan
# Rating: 4.5
#
# Business Name: Barshu
# Rating: 4.0
#
# Business Name: Canton Element
# Rating: 5.0
#
# Business Name: Bugis Street Brasserie
# Rating: 4.0
#
# Business Name: Gold Mine
# Rating: 4.0
#
# Business Name: Xi'an Impressions
# Rating: 4.5
#
# Business Name: Royal China
# Rating: 4.0
#
# Business Name: Chi Noodle
# Rating: 4.0
#
# Business Name: Joy King Lau
# Rating: 4.0
#
# Business Name: Sichuan Folk
# Rating: 4.0
#
# Business Name: Dragon Castle
# Rating: 4.0
#
# Business Name: Bun House
# Rating: 4.0
#
# Business Name: The Duck and Rice
# Rating: 4.0
#
# Business Name: Princess Garden Of Mayfair
# Rating: 4.0
#
# Business Name: Lotus
# Rating: 4.0
#
# Business Name: Yipin China Restaurant
# Rating: 4.0
#
# Business Name: Ping Pong Soho
# Rating: 3.5
#
# Business Name: A. Wong
# Rating: 4.0
#
# Business Name: Kai Of Mayfair
# Rating: 4.0
#
# Business Name: Pearl Liang
# Rating: 3.5
#
# Business Name: Firecracker
# Rating: 4.0
#
# Business Name: Yming
# Rating: 4.0
#
# Business Name: Four Seasons
# Rating: 3.5
#
# Business Name: Ma La
# Rating: 4.0
#
# Business Name: Good Earth
# Rating: 4.0
#
# Business Name: Wong Kei Restaurant
# Rating: 3.5
#
# Business Name: Ping Pong
# Rating: 3.5
#
# Business Name: Taiwan Village
# Rating: 4.5
#
# Business Name: Green Cottage
# Rating: 4.0
#
# Business Name: Dong Phuong
# Rating: 5.0
#
# Business Name: Yauatcha City
# Rating: 4.0
#
# Business Name: New Culture Revolution
# Rating: 4.0
#
# Business Name: Royal China
# Rating: 3.5
#
# Business Name: Mandarin Kitchen
# Rating: 4.0
#
# Business Name: Baiwei
# Rating: 3.5
#
# Business Name: Hutong
# Rating: 3.5
#
# Business Name: New Mayflower
# Rating: 4.0
#
# Business Name: Orient London
# Rating: 4.0
#
# Business Name: New City
# Rating: 4.5
#
# Business Name: Hiro
# Rating: 4.5
#
# Business Name: Royal China
# Rating: 3.5
#
# Business Name: Mamalan
# Rating: 4.0
#
# Business Name: Murger Han
# Rating: 4.5

# %%
# Practice with recursive function
def get_structure(response):
    if type(response) == dict:
        for key in response.keys():
            print('\n-----{}-----'.format(key.upper()))
            get_structure(response[key])
    elif type(response) == list:
        for item in response:
            get_structure(item)
    else:
        print(response)
        
i = 1
for business in response['businesses']:
    if i > 1:
        lines = ['-' for i in range(int(len(business['name'])/2))]
        print('{}-----------------------------------END BUSINESS {}----------------------------------{}\n\n\n'.format(''.join(lines), i-1, ''.join(lines)))
    print('----------------------------------------{}. {}----------------------------------------'.format(i, str(business['name']).upper()))
    get_structure(business)
    i += 1
# Out:
# ----------------------------------------1. HAKKASAN----------------------------------------
#
# -----ID-----
# h2cCoDNQOPd51HFwvuAGNg
#
# -----ALIAS-----
# hakkasan-london-3
#
# -----NAME-----
# Hakkasan
#
# -----IMAGE_URL-----
# https://s3-media2.fl.yelpcdn.com/bphoto/IcS9yzJnweDO4DsfJ94jAw/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/hakkasan-london-3?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 219
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# cantonese
#
# -----TITLE-----
# Cantonese
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.5171482803943
#
# -----LONGITUDE-----
# -0.13180578932657
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 8 Hanway Place
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# W1T 1HD
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 8 Hanway Place
# London W1T 1HD
# United Kingdom
#
# -----PHONE-----
# +442079277000
#
# -----DISPLAY_PHONE-----
# +44 20 7927 7000
#
# -----DISTANCE-----
# 558.9650039747677
# -----------------------------------------END BUSINESS 1----------------------------------------
#
#
#
# ----------------------------------------2. BAMBOO FLUTE----------------------------------------
#
# -----ID-----
# QE5aa5N-dbfvafLsjn7TVg
#
# -----ALIAS-----
# bamboo-flute-fitzrovia
#
# -----NAME-----
# Bamboo Flute
#
# -----IMAGE_URL-----
# https://s3-media3.fl.yelpcdn.com/bphoto/kYQZjHmzt8zy1634OsAsxQ/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/bamboo-flute-fitzrovia?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 28
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 4.5
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.5228746
#
# -----LONGITUDE-----
# -0.1418939
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# £
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 145 Cleveland Street
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# Fitzrovia
#
# -----ZIP_CODE-----
# W1T 6QH
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 145 Cleveland Street
# Fitzrovia W1T 6QH
# United Kingdom
#
# -----PHONE-----
# +442073872738
#
# -----DISPLAY_PHONE-----
# +44 20 7387 2738
#
# -----DISTANCE-----
# 1189.5082547156321
# ---------------------------------------END BUSINESS 2--------------------------------------
#
#
#
# ----------------------------------------3. YAUATCHA----------------------------------------
#
# -----ID-----
# sYwBQ7mJYhB35nn-_SZstQ
#
# -----ALIAS-----
# yauatcha-london-7
#
# -----NAME-----
# Yauatcha
#
# -----IMAGE_URL-----
# https://s3-media1.fl.yelpcdn.com/bphoto/G7Ydt9lmtWsUN1gRhlCRsw/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/yauatcha-london-7?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 460
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# dimsum
#
# -----TITLE-----
# Dim Sum
#
# -----ALIAS-----
# seafood
#
# -----TITLE-----
# Seafood
#
# -----ALIAS-----
# noodles
#
# -----TITLE-----
# Noodles
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.5137076071076
#
# -----LONGITUDE-----
# -0.135128831605189
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# £££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 15-17 Broadwick Street
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# W1F 0DL
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 15-17 Broadwick Street
# London W1F 0DL
# United Kingdom
#
# -----PHONE-----
# +442074948888
#
# -----DISPLAY_PHONE-----
# +44 20 7494 8888
#
# -----DISTANCE-----
# 112.59840998419494
# ----------------------------------------END BUSINESS 3---------------------------------------
#
#
#
# ----------------------------------------4. BAO - SOHO----------------------------------------
#
# -----ID-----
# xYYh1dd95idvwCoGZWq58g
#
# -----ALIAS-----
# bao-soho-london
#
# -----NAME-----
# BAO - Soho
#
# -----IMAGE_URL-----
# https://s3-media4.fl.yelpcdn.com/bphoto/L-08d4lsRSOe2HlIs1ZmfA/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/bao-soho-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 167
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# taiwanese
#
# -----TITLE-----
# Taiwanese
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.5132221949841
#
# -----LONGITUDE-----
# -0.136528484994449
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 53 Lexington Street
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# W1F 9AS
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 53 Lexington Street
# London W1F 9AS
# United Kingdom
#
# -----PHONE-----
# +442030192200
#
# -----DISPLAY_PHONE-----
# +44 20 3019 2200
#
# -----DISTANCE-----
# 58.47355609756945
# --------------------------------------------END BUSINESS 4-------------------------------------------
#
#
#
# ----------------------------------------5. LANZHOU NOODLE BAR----------------------------------------
#
# -----ID-----
# pdFiFtol9YI__9ROOXUIYA
#
# -----ALIAS-----
# lanzhou-noodle-bar-london
#
# -----NAME-----
# Lanzhou Noodle Bar
#
# -----IMAGE_URL-----
# https://s3-media4.fl.yelpcdn.com/bphoto/OMre4TNCrkDck3wqpUXbjQ/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/lanzhou-noodle-bar-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 313
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----ALIAS-----
# noodles
#
# -----TITLE-----
# Noodles
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.5116034713013
#
# -----LONGITUDE-----
# -0.127834377873126
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# £
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 33 Cranbourne Street
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# WC2H 7AD
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 33 Cranbourne Street
# London WC2H 7AD
# United Kingdom
#
# -----PHONE-----
# +442074674546
#
# -----DISPLAY_PHONE-----
# +44 20 7467 4546
#
# -----DISTANCE-----
# 578.4743547816091
# -------------------------------------------END BUSINESS 5------------------------------------------
#
#
#
# ----------------------------------------6. HAKKASAN MAYFAIR----------------------------------------
#
# -----ID-----
# chEEcQbc8PbidTeXK34H9g
#
# -----ALIAS-----
# hakkasan-mayfair-london-2
#
# -----NAME-----
# Hakkasan Mayfair
#
# -----IMAGE_URL-----
# https://s3-media2.fl.yelpcdn.com/bphoto/LX_W20RxnR5yzB3dTN6IdA/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/hakkasan-mayfair-london-2?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 116
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.5103202323384
#
# -----LONGITUDE-----
# -0.144935268434918
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 17 Bruton Street
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# W1J 6QB
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 17 Bruton Street
# London W1J 6QB
# United Kingdom
#
# -----PHONE-----
# +442079071888
#
# -----DISPLAY_PHONE-----
# +44 20 7907 1888
#
# -----DISTANCE-----
# 681.4450716267161
# ---------------------------------------END BUSINESS 6--------------------------------------
#
#
#
# ----------------------------------------7. SILK ROAD----------------------------------------
#
# -----ID-----
# 6iCxFP7Oc0qG_6ByenO0sw
#
# -----ALIAS-----
# silk-road-london-2
#
# -----NAME-----
# Silk Road
#
# -----IMAGE_URL-----
# https://s3-media3.fl.yelpcdn.com/bphoto/pUXusTIbeDRInvi6fkNjmA/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/silk-road-london-2?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 43
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 4.5
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.4739712
#
# -----LONGITUDE-----
# -0.0896081
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 49 Camberwell Church Street
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# SE5 8TR
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 49 Camberwell Church Street
# London SE5 8TR
# United Kingdom
#
# -----PHONE-----
# +442077034832
#
# -----DISPLAY_PHONE-----
# +44 20 7703 4832
#
# -----DISTANCE-----
# 5403.445838977789
# -------------------------------------END BUSINESS 7------------------------------------
#
#
#
# ----------------------------------------8. HUNAN----------------------------------------
#
# -----ID-----
# Mrv3dA42EioqBz50t_f24Q
#
# -----ALIAS-----
# hunan-london
#
# -----NAME-----
# Hunan
#
# -----IMAGE_URL-----
# https://s3-media3.fl.yelpcdn.com/bphoto/sEgrRrMVkWaky7Yc7dvdgg/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/hunan-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 38
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 4.5
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.490493
#
# -----LONGITUDE-----
# -0.1526547
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 51 Pimlico Road
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# SW1W 8NE
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 51 Pimlico Road
# London SW1W 8NE
# United Kingdom
#
# -----PHONE-----
# +442077305712
#
# -----DISPLAY_PHONE-----
# +44 20 7730 5712
#
# -----DISTANCE-----
# 2741.6022690860036
# --------------------------------------END BUSINESS 8-------------------------------------
#
#
#
# ----------------------------------------9. BARSHU----------------------------------------
#
# -----ID-----
# MpdG-D0nKwGEZp0ApTtBaA
#
# -----ALIAS-----
# barshu-london-2
#
# -----NAME-----
# Barshu
#
# -----IMAGE_URL-----
# https://s3-media2.fl.yelpcdn.com/bphoto/jaGznOhEvqqcJXKCYt12Ug/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/barshu-london-2?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 97
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# szechuan
#
# -----TITLE-----
# Szechuan
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.512835
#
# -----LONGITUDE-----
# -0.130857
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# £££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 28 Frith Street
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# W1D 5LF
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 28 Frith Street
# London W1D 5LF
# United Kingdom
#
# -----PHONE-----
# +442072878822
#
# -----DISPLAY_PHONE-----
# +44 20 7287 8822
#
# -----DISTANCE-----
# 357.1885184880618
# ------------------------------------------END BUSINESS 9-----------------------------------------
#
#
#
# ----------------------------------------10. CANTON ELEMENT----------------------------------------
#
# -----ID-----
# vtFvSTgUW9KICwDGtnQSug
#
# -----ALIAS-----
# canton-element-london
#
# -----NAME-----
# Canton Element
#
# -----IMAGE_URL-----
# https://s3-media4.fl.yelpcdn.com/bphoto/MMHfsdoHDpCmigvBr6y9bA/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/canton-element-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 12
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----ALIAS-----
# karaoke
#
# -----TITLE-----
# Karaoke
#
# -----RATING-----
# 5.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.519862
#
# -----LONGITUDE-----
# -0.117582
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 48 Red Lion Street
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# WC1R 4PF
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 48 Red Lion Street
# London WC1R 4PF
# United Kingdom
#
# -----PHONE-----
# +442072421515
#
# -----DISPLAY_PHONE-----
# +44 20 7242 1515
#
# -----DISTANCE-----
# 1501.0470490724267
# ----------------------------------------------END BUSINESS 10---------------------------------------------
#
#
#
# ----------------------------------------11. BUGIS STREET BRASSERIE----------------------------------------
#
# -----ID-----
# 5-_YNjtvoG-oYt1qAO3tVw
#
# -----ALIAS-----
# bugis-street-brasserie-london
#
# -----NAME-----
# Bugis Street Brasserie
#
# -----IMAGE_URL-----
# https://s3-media1.fl.yelpcdn.com/bphoto/kgtAwZ3oF2wh05ndSzQ1zA/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/bugis-street-brasserie-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 44
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----ALIAS-----
# singaporean
#
# -----TITLE-----
# Singaporean
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.4936621211568
#
# -----LONGITUDE-----
# -0.183931280273902
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# Millennium Hotels & Resorts
#
# -----ADDRESS2-----
# 4-18 Harrington Gardens
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# SW7 4LH
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# Millennium Hotels & Resorts
# 4-18 Harrington Gardens
# London SW7 4LH
# United Kingdom
#
# -----PHONE-----
# +442073316211
#
# -----DISPLAY_PHONE-----
# +44 20 7331 6211
#
# -----DISTANCE-----
# 3946.1405823998143
# ---------------------------------------END BUSINESS 11--------------------------------------
#
#
#
# ----------------------------------------12. GOLD MINE----------------------------------------
#
# -----ID-----
# 3ea8x8r0gsVy8ltQycldsA
#
# -----ALIAS-----
# gold-mine-london
#
# -----NAME-----
# Gold Mine
#
# -----IMAGE_URL-----
# https://s3-media2.fl.yelpcdn.com/bphoto/aihm1QdPS5Mq79T_9rP7tA/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/gold-mine-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 70
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.5133018493652
#
# -----LONGITUDE-----
# -0.187491998076439
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 102 Queensway
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# W2 3RR
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 102 Queensway
# London W2 3RR
# United Kingdom
#
# -----PHONE-----
# +442077928331
#
# -----DISPLAY_PHONE-----
# +44 20 7792 8331
#
# -----DISTANCE-----
# 3571.4713192257427
# -------------------------------------------END BUSINESS 12------------------------------------------
#
#
#
# ----------------------------------------13. XI'AN IMPRESSIONS----------------------------------------
#
# -----ID-----
# Aar0fS6vSWRhQc7WddYagg
#
# -----ALIAS-----
# xian-impressions-london
#
# -----NAME-----
# Xi'an Impressions
#
# -----IMAGE_URL-----
# https://s3-media4.fl.yelpcdn.com/bphoto/VDbI_euzpp8AfjMF2-ndIw/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/xian-impressions-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 26
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# szechuan
#
# -----TITLE-----
# Szechuan
#
# -----RATING-----
# 4.5
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.5539006581936
#
# -----LONGITUDE-----
# -0.110344699913454
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 117 Benwell Road
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# N7 7BW
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 117 Benwell Road
# London N7 7BW
# United Kingdom
#
# -----PHONE-----
# +442034410191
#
# -----DISPLAY_PHONE-----
# +44 20 3441 0191
#
# -----DISTANCE-----
# 4897.827262129786
# ----------------------------------------END BUSINESS 13---------------------------------------
#
#
#
# ----------------------------------------14. ROYAL CHINA----------------------------------------
#
# -----ID-----
# 2NdnxONuSAsDkQPhU919tQ
#
# -----ALIAS-----
# royal-china-london-2
#
# -----NAME-----
# Royal China
#
# -----IMAGE_URL-----
# https://s3-media3.fl.yelpcdn.com/bphoto/Mpn3L7JpUdeAJqG0d7Ub3w/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/royal-china-london-2?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 96
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# dimsum
#
# -----TITLE-----
# Dim Sum
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.5105005571439
#
# -----LONGITUDE-----
# -0.187244316153717
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 13 Queensway
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# W2 4QJ
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 13 Queensway
# London W2 4QJ
# United Kingdom
#
# -----PHONE-----
# +442072212535
#
# -----DISPLAY_PHONE-----
# +44 20 7221 2535
#
# -----DISTANCE-----
# 3558.785103799373
# ----------------------------------------END BUSINESS 14---------------------------------------
#
#
#
# ----------------------------------------15. CHI NOODLE----------------------------------------
#
# -----ID-----
# AwwZIdmScSHhM54Wh8P8JQ
#
# -----ALIAS-----
# chi-noodle-london
#
# -----NAME-----
# Chi Noodle
#
# -----IMAGE_URL-----
# https://s3-media1.fl.yelpcdn.com/bphoto/Wk6KBsJ4SWYtUSBDm1xljg/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/chi-noodle-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 29
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----ALIAS-----
# bars
#
# -----TITLE-----
# Bars
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.5135092
#
# -----LONGITUDE-----
# -0.1053698
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 5 New Bridge Street
#
# -----ADDRESS2-----
# Bride Court
#
# -----ADDRESS3-----
# None
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# EC4V 6AB
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 5 New Bridge Street
# Bride Court
# London EC4V 6AB
# United Kingdom
#
# -----PHONE-----
# +442073532409
#
# -----DISPLAY_PHONE-----
# +44 20 7353 2409
#
# -----DISTANCE-----
# 2117.888856995979
# -----------------------------------------END BUSINESS 15----------------------------------------
#
#
#
# ----------------------------------------16. JOY KING LAU----------------------------------------
#
# -----ID-----
# aOSZ-xTyLrR2LX6-Wgf6OQ
#
# -----ALIAS-----
# joy-king-lau-london
#
# -----NAME-----
# Joy King Lau
#
# -----IMAGE_URL-----
# https://s3-media1.fl.yelpcdn.com/bphoto/u2yRwJcmmaOtyOX3T9ALDA/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/joy-king-lau-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 134
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# dimsum
#
# -----TITLE-----
# Dim Sum
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.511104
#
# -----LONGITUDE-----
# -0.13113
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 3 Leicester Street
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# WC2H 7BL
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 3 Leicester Street
# London WC2H 7BL
# United Kingdom
#
# -----PHONE-----
# +442074371132
#
# -----DISPLAY_PHONE-----
# +44 20 7437 1132
#
# -----DISTANCE-----
# 385.48318993171404
# -----------------------------------------END BUSINESS 16----------------------------------------
#
#
#
# ----------------------------------------17. SICHUAN FOLK----------------------------------------
#
# -----ID-----
# xriXls0Dn4ru2ODF6fDWhQ
#
# -----ALIAS-----
# sichuan-folk-london
#
# -----NAME-----
# Sichuan Folk
#
# -----IMAGE_URL-----
# https://s3-media3.fl.yelpcdn.com/bphoto/nb1TNrVfOvCpUW1pS_MVrw/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/sichuan-folk-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 65
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.520178
#
# -----LONGITUDE-----
# -0.072425
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 32 Hanbury Street
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# E1 6QR
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 32 Hanbury Street
# London E1 6QR
# United Kingdom
#
# -----PHONE-----
# +442072474735
#
# -----DISPLAY_PHONE-----
# +44 20 7247 4735
#
# -----DISTANCE-----
# 4471.20821766474
# -----------------------------------------END BUSINESS 17----------------------------------------
#
#
#
# ----------------------------------------18. DRAGON CASTLE----------------------------------------
#
# -----ID-----
# 3EZWvxhLjYEqAQyg1VJ9Zg
#
# -----ALIAS-----
# dragon-castle-london
#
# -----NAME-----
# Dragon Castle
#
# -----IMAGE_URL-----
# https://s3-media1.fl.yelpcdn.com/bphoto/qF_dr86TN3GIToGO6lhZFA/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/dragon-castle-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 46
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# dimsum
#
# -----TITLE-----
# Dim Sum
#
# -----ALIAS-----
# cantonese
#
# -----TITLE-----
# Cantonese
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.492101
#
# -----LONGITUDE-----
# -0.098573
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 100 Walworth Road
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# SE17 1JL
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 100 Walworth Road
# London SE17 1JL
# United Kingdom
#
# -----PHONE-----
# +442072773388
#
# -----DISPLAY_PHONE-----
# +44 20 7277 3388
#
# -----DISTANCE-----
# 3484.935669306307
# ---------------------------------------END BUSINESS 18--------------------------------------
#
#
#
# ----------------------------------------19. BUN HOUSE----------------------------------------
#
# -----ID-----
# 4wnP2JAuR92yoS3TybKyRA
#
# -----ALIAS-----
# bun-house-london
#
# -----NAME-----
# Bun House
#
# -----IMAGE_URL-----
# https://s3-media2.fl.yelpcdn.com/bphoto/0pEoyRDbUPkPRs3D7wBS4A/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/bun-house-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 29
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.51365
#
# -----LONGITUDE-----
# -0.130452
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 23-24 Greek Street
#
# -----ADDRESS2-----
# Soho
#
# -----ADDRESS3-----
# None
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# W1D 4DZ
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 23-24 Greek Street
# Soho
# London W1D 4DZ
# United Kingdom
#
# -----PHONE-----
# +442080179888
#
# -----DISPLAY_PHONE-----
# +44 20 8017 9888
#
# -----DISTANCE-----
# 391.48496685335056
# -------------------------------------------END BUSINESS 19------------------------------------------
#
#
#
# ----------------------------------------20. THE DUCK AND RICE----------------------------------------
#
# -----ID-----
# hdp4iZf_iUmYzDrvHjblPw
#
# -----ALIAS-----
# the-duck-and-rice-london
#
# -----NAME-----
# The Duck and Rice
#
# -----IMAGE_URL-----
# https://s3-media4.fl.yelpcdn.com/bphoto/8JaqXM1qCqWTdqzIphfJ1Q/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/the-duck-and-rice-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 58
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----ALIAS-----
# bars
#
# -----TITLE-----
# Bars
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.513487
#
# -----LONGITUDE-----
# -0.135082
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# £££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 90 Berwick Street
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# W1F 0QB
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 90 Berwick Street
# London W1F 0QB
# United Kingdom
#
# -----PHONE-----
# +442033277888
#
# -----DISPLAY_PHONE-----
# +44 20 3327 7888
#
# -----DISTANCE-----
# 98.56398403934607
# ------------------------------------------------END BUSINESS 20-----------------------------------------------
#
#
#
# ----------------------------------------21. PRINCESS GARDEN OF MAYFAIR----------------------------------------
#
# -----ID-----
# heTzmXTNQeuXvVhdpFJwaA
#
# -----ALIAS-----
# princess-garden-of-mayfair-london
#
# -----NAME-----
# Princess Garden Of Mayfair
#
# -----IMAGE_URL-----
# https://s3-media3.fl.yelpcdn.com/bphoto/zmKhu0P6idUlm8G14Q9B-Q/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/princess-garden-of-mayfair-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 51
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.512773
#
# -----LONGITUDE-----
# -0.153083
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# £££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 8-10 N Audley Street
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# W1K 6ZD
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 8-10 N Audley Street
# London W1K 6ZD
# United Kingdom
#
# -----PHONE-----
# +442074933223
#
# -----DISPLAY_PHONE-----
# +44 20 7493 3223
#
# -----DISTANCE-----
# 1190.7587274700359
# -------------------------------------END BUSINESS 21------------------------------------
#
#
#
# ----------------------------------------22. LOTUS----------------------------------------
#
# -----ID-----
# eMqkAjMsvsqjZEwuVwh2dA
#
# -----ALIAS-----
# lotus-london
#
# -----NAME-----
# Lotus
#
# -----IMAGE_URL-----
# https://s3-media2.fl.yelpcdn.com/bphoto/6-YG5gxUwQqB_MVryDnxYQ/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/lotus-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 61
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.4970261273306
#
# -----LONGITUDE-----
# -0.0161981516153809
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 9 Oakland Quay
#
# -----ADDRESS2-----
# Inner Millwall Dock
#
# -----ADDRESS3-----
# None
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# E14 9EA
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 9 Oakland Quay
# Inner Millwall Dock
# London E14 9EA
# United Kingdom
#
# -----PHONE-----
# +442075156445
#
# -----DISPLAY_PHONE-----
# +44 20 7515 6445
#
# -----DISTANCE-----
# 8473.138078439868
# ----------------------------------------------END BUSINESS 22---------------------------------------------
#
#
#
# ----------------------------------------23. YIPIN CHINA RESTAURANT----------------------------------------
#
# -----ID-----
# IeMFeX8iu-C1gYaM-sZteA
#
# -----ALIAS-----
# yipin-china-restaurant-london
#
# -----NAME-----
# Yipin China Restaurant
#
# -----IMAGE_URL-----
# https://s3-media3.fl.yelpcdn.com/bphoto/im88zV5X2dPNzEo9Bf-mDQ/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/yipin-china-restaurant-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 34
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.537275
#
# -----LONGITUDE-----
# -0.106626
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 70-72 Liverpool Road
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# N1 0QD
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 70-72 Liverpool Road
# London N1 0QD
# United Kingdom
#
# -----PHONE-----
# +442073543388
#
# -----DISPLAY_PHONE-----
# +44 20 7354 3388
#
# -----DISTANCE-----
# 3391.102734013863
# ------------------------------------------END BUSINESS 23-----------------------------------------
#
#
#
# ----------------------------------------24. PING PONG SOHO----------------------------------------
#
# -----ID-----
# rGVVA2R6M3Vs8eMRWUQgEg
#
# -----ALIAS-----
# ping-pong-soho-london
#
# -----NAME-----
# Ping Pong Soho
#
# -----IMAGE_URL-----
# https://s3-media3.fl.yelpcdn.com/bphoto/MPjY4Pn8VouDis_dHyJXKg/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/ping-pong-soho-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 129
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# dimsum
#
# -----TITLE-----
# Dim Sum
#
# -----RATING-----
# 3.5
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.5144372406878
#
# -----LONGITUDE-----
# -0.13853844255209
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 45 Great Marlborough Street
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# W1F 7JL
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 45 Great Marlborough Street
# London W1F 7JL
# United Kingdom
#
# -----PHONE-----
# +442078516969
#
# -----DISPLAY_PHONE-----
# +44 20 7851 6969
#
# -----DISTANCE-----
# 252.31035150431586
# --------------------------------------END BUSINESS 24-------------------------------------
#
#
#
# ----------------------------------------25. A. WONG----------------------------------------
#
# -----ID-----
# UG46BO-eDyaKPUVGOtgYNw
#
# -----ALIAS-----
# a-wong-london
#
# -----NAME-----
# A. Wong
#
# -----IMAGE_URL-----
# https://s3-media4.fl.yelpcdn.com/bphoto/6pLMa3TXyzDXhsORF-fogA/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/a-wong-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 47
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.4930394
#
# -----LONGITUDE-----
# -0.1406692
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 70-71 Wilton Road
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# SW1V 1DE
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 70-71 Wilton Road
# London SW1V 1DE
# United Kingdom
#
# -----PHONE-----
# +442078288931
#
# -----DISPLAY_PHONE-----
# +44 20 7828 8931
#
# -----DISTANCE-----
# 2230.534863152845
# ------------------------------------------END BUSINESS 25-----------------------------------------
#
#
#
# ----------------------------------------26. KAI OF MAYFAIR----------------------------------------
#
# -----ID-----
# R6wtvD4TqQsDFi2D0oilPg
#
# -----ALIAS-----
# kai-of-mayfair-london
#
# -----NAME-----
# Kai Of Mayfair
#
# -----IMAGE_URL-----
# https://s3-media1.fl.yelpcdn.com/bphoto/uEMVsFL-nrYAixnPwA_SRQ/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/kai-of-mayfair-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 37
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.50875
#
# -----LONGITUDE-----
# -0.151732
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 65 S Audley Street
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# W1K 2QU
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 65 S Audley Street
# London W1K 2QU
# United Kingdom
#
# -----PHONE-----
# +442074938988
#
# -----DISPLAY_PHONE-----
# +44 20 7493 8988
#
# -----DISTANCE-----
# 1170.6555568486363
# ----------------------------------------END BUSINESS 26---------------------------------------
#
#
#
# ----------------------------------------27. PEARL LIANG----------------------------------------
#
# -----ID-----
# BuFA-nSzJxJcG1ZWEj4AYw
#
# -----ALIAS-----
# pearl-liang-london
#
# -----NAME-----
# Pearl Liang
#
# -----IMAGE_URL-----
# https://s3-media2.fl.yelpcdn.com/bphoto/oJXKFlwrJcomFFoR3RWaJg/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/pearl-liang-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 83
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# dimsum
#
# -----TITLE-----
# Dim Sum
#
# -----RATING-----
# 3.5
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.5192622106976
#
# -----LONGITUDE-----
# -0.181188583374023
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 8 Sheldon Square
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# W2 6EZ
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 8 Sheldon Square
# London W2 6EZ
# United Kingdom
#
# -----PHONE-----
# +442072897000
#
# -----DISPLAY_PHONE-----
# +44 20 7289 7000
#
# -----DISTANCE-----
# 3210.4704169144943
# ----------------------------------------END BUSINESS 27---------------------------------------
#
#
#
# ----------------------------------------28. FIRECRACKER----------------------------------------
#
# -----ID-----
# y9MWERu8ULGHhMKaDn8F2Q
#
# -----ALIAS-----
# firecracker-london
#
# -----NAME-----
# Firecracker
#
# -----IMAGE_URL-----
# https://s3-media4.fl.yelpcdn.com/bphoto/LDmgSAH6aYigccBqn5EkiA/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/firecracker-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 41
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# asianfusion
#
# -----TITLE-----
# Asian Fusion
#
# -----ALIAS-----
# karaoke
#
# -----TITLE-----
# Karaoke
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.4949849
#
# -----LONGITUDE-----
# -0.1271241
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 44 Horseferry Road
#
# -----ADDRESS2-----
# Westminster
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# SW1P 2AF
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 44 Horseferry Road
# Westminster
# London SW1P 2AF
# United Kingdom
#
# -----PHONE-----
# +442072224680
#
# -----DISPLAY_PHONE-----
# +44 20 7222 4680
#
# -----DISTANCE-----
# 2089.3863287375334
# -------------------------------------END BUSINESS 28------------------------------------
#
#
#
# ----------------------------------------29. YMING----------------------------------------
#
# -----ID-----
# uaWX6Rlt91KbJvFOEr2_DA
#
# -----ALIAS-----
# yming-london
#
# -----NAME-----
# Yming
#
# -----IMAGE_URL-----
# https://s3-media4.fl.yelpcdn.com/bphoto/GW_e9wqnGLkdoxMkAeftyg/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/yming-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 32
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.51298
#
# -----LONGITUDE-----
# -0.130376
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# £££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 35-36 Greek Street
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# W1D 5DL
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 35-36 Greek Street
# London W1D 5DL
# United Kingdom
#
# -----PHONE-----
# +442077342721
#
# -----DISPLAY_PHONE-----
# +44 20 7734 2721
#
# -----DISTANCE-----
# 390.3300443859922
# -----------------------------------------END BUSINESS 29----------------------------------------
#
#
#
# ----------------------------------------30. FOUR SEASONS----------------------------------------
#
# -----ID-----
# 6yqhDUickUwxIwaIticYOg
#
# -----ALIAS-----
# four-seasons-london
#
# -----NAME-----
# Four Seasons
#
# -----IMAGE_URL-----
# https://s3-media3.fl.yelpcdn.com/bphoto/uBTQDUKcP3yrkHnzh2f5LQ/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/four-seasons-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 99
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 3.5
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.5130037
#
# -----LONGITUDE-----
# -0.1874014
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 84 Queensway
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# W2 3RL
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 84 Queensway
# London W2 3RL
# United Kingdom
#
# -----PHONE-----
# +442072294320
#
# -----DISPLAY_PHONE-----
# +44 20 7229 4320
#
# -----DISTANCE-----
# 3558.211280376721
# -------------------------------------END BUSINESS 30------------------------------------
#
#
#
# ----------------------------------------31. MA LA----------------------------------------
#
# -----ID-----
# M2sGFRvTvozQ5Z3bw6JPjQ
#
# -----ALIAS-----
# ma-la-london
#
# -----NAME-----
# Ma La
#
# -----IMAGE_URL-----
# https://s3-media2.fl.yelpcdn.com/bphoto/WagdFT5JHxKWQT-NatdrZg/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/ma-la-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 24
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# dimsum
#
# -----TITLE-----
# Dim Sum
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.4967879034045
#
# -----LONGITUDE-----
# -0.131008437607831
#
# -----TRANSACTIONS-----
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 37 Monck Street
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# SW1P 2BL
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 37 Monck Street
# London SW1P 2BL
# United Kingdom
#
# -----PHONE-----
# +442072222218
#
# -----DISPLAY_PHONE-----
# +44 20 7222 2218
#
# -----DISTANCE-----
# 1816.9696172196484
# ----------------------------------------END BUSINESS 31---------------------------------------
#
#
#
# ----------------------------------------32. GOOD EARTH----------------------------------------
#
# -----ID-----
# Ame6cZG8I-DQ5tkMtdyyeg
#
# -----ALIAS-----
# good-earth-london-2
#
# -----NAME-----
# Good Earth
#
# -----IMAGE_URL-----
# https://s3-media1.fl.yelpcdn.com/bphoto/cpLh8fy-R13IaCVYaOcS3g/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/good-earth-london-2?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 39
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.4968451
#
# -----LONGITUDE-----
# -0.1684174
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 233 Brompton Road
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# SW3 2EP
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 233 Brompton Road
# London SW3 2EP
# United Kingdom
#
# -----PHONE-----
# +442075843658
#
# -----DISPLAY_PHONE-----
# +44 20 7584 3658
#
# -----DISTANCE-----
# 2867.1408887047874
# --------------------------------------------END BUSINESS 32-------------------------------------------
#
#
#
# ----------------------------------------33. WONG KEI RESTAURANT----------------------------------------
#
# -----ID-----
# 7pwy404wcQGvGzM9RjxWdQ
#
# -----ALIAS-----
# wong-kei-restaurant-london
#
# -----NAME-----
# Wong Kei Restaurant
#
# -----IMAGE_URL-----
# https://s3-media4.fl.yelpcdn.com/bphoto/FRS766QUY4JPHIC8Hpi44A/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/wong-kei-restaurant-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 195
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 3.5
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.5115375
#
# -----LONGITUDE-----
# -0.132421
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# £
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 41-43 Wardour Street
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# W1D 6PY
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 41-43 Wardour Street
# London W1D 6PY
# United Kingdom
#
# -----PHONE-----
# +442074378408
#
# -----DISPLAY_PHONE-----
# +44 20 7437 8408
#
# -----DISTANCE-----
# 289.13121319043125
# ---------------------------------------END BUSINESS 33--------------------------------------
#
#
#
# ----------------------------------------34. PING PONG----------------------------------------
#
# -----ID-----
# lfUDW3AFKicfSZivkYVKBA
#
# -----ALIAS-----
# ping-pong-london-32
#
# -----NAME-----
# Ping Pong
#
# -----IMAGE_URL-----
# https://s3-media2.fl.yelpcdn.com/bphoto/WGm8kZfQIplRb_lOW5CSyQ/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/ping-pong-london-32?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 72
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# dimsum
#
# -----TITLE-----
# Dim Sum
#
# -----ALIAS-----
# tea
#
# -----TITLE-----
# Tea Rooms
#
# -----ALIAS-----
# cocktailbars
#
# -----TITLE-----
# Cocktail Bars
#
# -----RATING-----
# 3.5
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.5153116
#
# -----LONGITUDE-----
# -0.150888
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 29 A James Street
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# W1U 1DZ
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 29 A James Street
# London W1U 1DZ
# United Kingdom
#
# -----PHONE-----
# +442070343100
#
# -----DISPLAY_PHONE-----
# +44 20 7034 3100
#
# -----DISTANCE-----
# 1069.3451404139034
# ------------------------------------------END BUSINESS 34-----------------------------------------
#
#
#
# ----------------------------------------35. TAIWAN VILLAGE----------------------------------------
#
# -----ID-----
# CJkYOQLygyT9k3vl3mmG5w
#
# -----ALIAS-----
# taiwan-village-london
#
# -----NAME-----
# Taiwan Village
#
# -----IMAGE_URL-----
# https://s3-media4.fl.yelpcdn.com/bphoto/UTqWt54x-wDPFqaURBVi2Q/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/taiwan-village-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 16
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# taiwanese
#
# -----TITLE-----
# Taiwanese
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 4.5
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.4855449
#
# -----LONGITUDE-----
# -0.2020701
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 85 Lillie Road
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# SW6 1UD
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 85 Lillie Road
# London SW6 1UD
# United Kingdom
#
# -----PHONE-----
# +442073812900
#
# -----DISPLAY_PHONE-----
# +44 20 7381 2900
#
# -----DISTANCE-----
# 5491.206323167088
# -----------------------------------------END BUSINESS 35----------------------------------------
#
#
#
# ----------------------------------------36. GREEN COTTAGE----------------------------------------
#
# -----ID-----
# vjbJN0mucBjlddFt1Ka22g
#
# -----ALIAS-----
# green-cottage-london
#
# -----NAME-----
# Green Cottage
#
# -----IMAGE_URL-----
# https://s3-media3.fl.yelpcdn.com/bphoto/Pd3HqisfyKcExtsMen-TeA/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/green-cottage-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 21
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.5458012795971
#
# -----LONGITUDE-----
# -0.176575183868408
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 9 New College Parade
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# NW3 5EP
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 9 New College Parade
# London NW3 5EP
# United Kingdom
#
# -----PHONE-----
# +442077227892
#
# -----DISPLAY_PHONE-----
# +44 20 7722 7892
#
# -----DISTANCE-----
# 4618.6795485167295
# ----------------------------------------END BUSINESS 36---------------------------------------
#
#
#
# ----------------------------------------37. DONG PHUONG----------------------------------------
#
# -----ID-----
# GkX3yV3ggecmmemw7MhS9Q
#
# -----ALIAS-----
# dong-phuong-london
#
# -----NAME-----
# Dong Phuong
#
# -----IMAGE_URL-----
# https://s3-media2.fl.yelpcdn.com/bphoto/3T8k9FYdVMPP-d4qfrIR7w/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/dong-phuong-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 6
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----ALIAS-----
# thai
#
# -----TITLE-----
# Thai
#
# -----RATING-----
# 5.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.453886
#
# -----LONGITUDE-----
# -0.245483
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 32 Roehampton High Street
#
# -----ADDRESS2-----
# Roehampton
#
# -----ADDRESS3-----
# None
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# SW15 4HJ
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 32 Roehampton High Street
# Roehampton
# London SW15 4HJ
# United Kingdom
#
# -----PHONE-----
# +442087883888
#
# -----DISPLAY_PHONE-----
# +44 20 8788 3888
#
# -----DISTANCE-----
# 10024.358410964413
# -----------------------------------------END BUSINESS 37----------------------------------------
#
#
#
# ----------------------------------------38. YAUATCHA CITY----------------------------------------
#
# -----ID-----
# 2G0a1v9ubpNO_wADUVgs3A
#
# -----ALIAS-----
# yauatcha-city-london
#
# -----NAME-----
# Yauatcha City
#
# -----IMAGE_URL-----
# https://s3-media2.fl.yelpcdn.com/bphoto/oRQcKVOkrAdU2qBZbvJxwA/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/yauatcha-city-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 33
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# dimsum
#
# -----TITLE-----
# Dim Sum
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.5188478034811
#
# -----LONGITUDE-----
# -0.0844600399504998
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# £££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 2 Broadgate Circle
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# EC2M 7UR
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 2 Broadgate Circle
# London EC2M 7UR
# United Kingdom
#
# -----PHONE-----
# +442038179888
#
# -----DISPLAY_PHONE-----
# +44 20 3817 9888
#
# -----DISTANCE-----
# 3625.489644058402
# ----------------------------------------------END BUSINESS 38---------------------------------------------
#
#
#
# ----------------------------------------39. NEW CULTURE REVOLUTION----------------------------------------
#
# -----ID-----
# 7LMRibjYvu1I0vuxU5taPg
#
# -----ALIAS-----
# new-culture-revolution-london-2
#
# -----NAME-----
# New Culture Revolution
#
# -----IMAGE_URL-----
# https://s3-media3.fl.yelpcdn.com/bphoto/nP-28DkZIAMA77ydHmytbg/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/new-culture-revolution-london-2?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 29
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.484645
#
# -----LONGITUDE-----
# -0.174931
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# £
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 305 Kings Road
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# SW3 5EP
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 305 Kings Road
# London SW3 5EP
# United Kingdom
#
# -----PHONE-----
# +442073529281
#
# -----DISPLAY_PHONE-----
# +44 20 7352 9281
#
# -----DISTANCE-----
# 4133.66614069431
# ----------------------------------------END BUSINESS 39---------------------------------------
#
#
#
# ----------------------------------------40. ROYAL CHINA----------------------------------------
#
# -----ID-----
# neMkWvqA_HOCzo2fvoI3sw
#
# -----ALIAS-----
# royal-china-london-7
#
# -----NAME-----
# Royal China
#
# -----IMAGE_URL-----
# https://s3-media1.fl.yelpcdn.com/bphoto/bQ67GzjP9zCMHfznxX7u_g/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/royal-china-london-7?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 75
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 3.5
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.5055789413133
#
# -----LONGITUDE-----
# -0.0280016434014305
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 30 Westferry Circus
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# E14 8RR
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 30 Westferry Circus
# London E14 8RR
# United Kingdom
#
# -----PHONE-----
# +442077190888
#
# -----DISPLAY_PHONE-----
# +44 20 7719 0888
#
# -----DISTANCE-----
# 7514.566037591502
# -------------------------------------------END BUSINESS 40------------------------------------------
#
#
#
# ----------------------------------------41. MANDARIN KITCHEN----------------------------------------
#
# -----ID-----
# r6e1riScojLlPMhn2kK1Jw
#
# -----ALIAS-----
# mandarin-kitchen-london-2
#
# -----NAME-----
# Mandarin Kitchen
#
# -----IMAGE_URL-----
# https://s3-media2.fl.yelpcdn.com/bphoto/arQZ6v9PEjTqLhFz_Y7d4Q/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/mandarin-kitchen-london-2?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 40
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.510816
#
# -----LONGITUDE-----
# -0.186891
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 14-16 Queensway
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# W2 3RX
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 14-16 Queensway
# London W2 3RX
# United Kingdom
#
# -----PHONE-----
# +442077279012
#
# -----DISPLAY_PHONE-----
# +44 20 7727 9012
#
# -----DISTANCE-----
# 3531.9846996809965
# --------------------------------------END BUSINESS 41-------------------------------------
#
#
#
# ----------------------------------------42. BAIWEI----------------------------------------
#
# -----ID-----
# mDUKapRhtOIpTFczScuvRg
#
# -----ALIAS-----
# baiwei-london
#
# -----NAME-----
# Baiwei
#
# -----IMAGE_URL-----
# https://s3-media4.fl.yelpcdn.com/bphoto/wZGTQQ_E9T7e-J8x06E5bw/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/baiwei-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 54
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 3.5
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.5117895
#
# -----LONGITUDE-----
# -0.1291729
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 8 Little Newport Street
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# WC2H 7JJ
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 8 Little Newport Street
# London WC2H 7JJ
# United Kingdom
#
# -----PHONE-----
# +442074943605
#
# -----DISPLAY_PHONE-----
# +44 20 7494 3605
#
# -----DISTANCE-----
# 483.5849731601068
# --------------------------------------END BUSINESS 42-------------------------------------
#
#
#
# ----------------------------------------43. HUTONG----------------------------------------
#
# -----ID-----
# GHAsS9cIM23hqoCol53KRA
#
# -----ALIAS-----
# hutong-london
#
# -----NAME-----
# Hutong
#
# -----IMAGE_URL-----
# https://s3-media3.fl.yelpcdn.com/bphoto/0CvGPblswZK9Qs-m21Gj6Q/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/hutong-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 82
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 3.5
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.5042658217118
#
# -----LONGITUDE-----
# -0.0863956051376916
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# £££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# Level 33
#
# -----ADDRESS2-----
# The Shard
#
# -----ADDRESS3-----
# 31 St Thomas Street
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# SE1 9RY
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# Level 33
# The Shard
# 31 St Thomas Street
# London SE1 9RY
# United Kingdom
#
# -----PHONE-----
# +442030111257
#
# -----DISPLAY_PHONE-----
# +44 20 3011 1257
#
# -----DISTANCE-----
# 3559.8414471826172
# -----------------------------------------END BUSINESS 43----------------------------------------
#
#
#
# ----------------------------------------44. NEW MAYFLOWER----------------------------------------
#
# -----ID-----
# IX34i9H1OKjesMp_-lhcpA
#
# -----ALIAS-----
# new-mayflower-london
#
# -----NAME-----
# New Mayflower
#
# -----IMAGE_URL-----
# https://s3-media2.fl.yelpcdn.com/bphoto/9uzF_qDzD0AAONf5-ax4Kg/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/new-mayflower-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 37
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.511849
#
# -----LONGITUDE-----
# -0.131981
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 68-70 Shaftesbury Avenue
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# W1D 6LY
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 68-70 Shaftesbury Avenue
# London W1D 6LY
# United Kingdom
#
# -----PHONE-----
# +442077349207
#
# -----DISPLAY_PHONE-----
# +44 20 7734 9207
#
# -----DISTANCE-----
# 296.13022315290414
# -----------------------------------------END BUSINESS 44----------------------------------------
#
#
#
# ----------------------------------------45. ORIENT LONDON----------------------------------------
#
# -----ID-----
# cxpKr3MfJKvpR77DR1JdIA
#
# -----ALIAS-----
# orient-london-london
#
# -----NAME-----
# Orient London
#
# -----IMAGE_URL-----
# https://s3-media3.fl.yelpcdn.com/bphoto/oIX0H3FzqjO3rau8j5Qj8A/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/orient-london-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 30
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# asianfusion
#
# -----TITLE-----
# Asian Fusion
#
# -----ALIAS-----
# dimsum
#
# -----TITLE-----
# Dim Sum
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.5108757019043
#
# -----LONGITUDE-----
# -0.131764858961105
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 15 Wardour Street
#
# -----ADDRESS2-----
# None
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# W1D 6PH
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 15 Wardour Street
# London W1D 6PH
# United Kingdom
#
# -----PHONE-----
# +442079898880
#
# -----DISPLAY_PHONE-----
# +44 20 7989 8880
#
# -----DISTANCE-----
# 350.3245996866791
# ---------------------------------------END BUSINESS 45--------------------------------------
#
#
#
# ----------------------------------------46. NEW CITY----------------------------------------
#
# -----ID-----
# fknsE8zZ0_sP-n35Z4RRKw
#
# -----ALIAS-----
# new-city-london
#
# -----NAME-----
# New City
#
# -----IMAGE_URL-----
# https://s3-media2.fl.yelpcdn.com/bphoto/rbRdPLHUTjGWqjFR56PRXA/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/new-city-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 8
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 4.5
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.475829
#
# -----LONGITUDE-----
# -0.14893
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 183-185 Battersea Park Road
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# SW11 4LB
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 183-185 Battersea Park Road
# London SW11 4LB
# United Kingdom
#
# -----PHONE-----
# +442077209928
#
# -----DISPLAY_PHONE-----
# +44 20 7720 9928
#
# -----DISTANCE-----
# 4216.931901325764
# -------------------------------------END BUSINESS 46------------------------------------
#
#
#
# ----------------------------------------47. HIRO----------------------------------------
#
# -----ID-----
# CpfJcfFlQdgqA4qjH02uBA
#
# -----ALIAS-----
# hiro-london
#
# -----NAME-----
# Hiro
#
# -----IMAGE_URL-----
# https://s3-media3.fl.yelpcdn.com/bphoto/gX997jxzinVc-fvEuBhvig/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/hiro-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 11
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----RATING-----
# 4.5
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.5377
#
# -----LONGITUDE-----
# -0.184907
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 100 Boundary Road
#
# -----ADDRESS2-----
# Saint John's Wood
#
# -----ADDRESS3-----
# None
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# NW8 0RH
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 100 Boundary Road
# Saint John's Wood
# London NW8 0RH
# United Kingdom
#
# -----PHONE-----
# +442073726720
#
# -----DISPLAY_PHONE-----
# +44 20 7372 6720
#
# -----DISTANCE-----
# 4371.8172739795555
# ----------------------------------------END BUSINESS 47---------------------------------------
#
#
#
# ----------------------------------------48. ROYAL CHINA----------------------------------------
#
# -----ID-----
# -50FYxMbPA_qVyv6uVfqsQ
#
# -----ALIAS-----
# royal-china-london-4
#
# -----NAME-----
# Royal China
#
# -----IMAGE_URL-----
# https://s3-media2.fl.yelpcdn.com/bphoto/naV7h48Qt-PGHdjLcuySsg/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/royal-china-london-4?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 72
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# dimsum
#
# -----TITLE-----
# Dim Sum
#
# -----RATING-----
# 3.5
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.5178304458283
#
# -----LONGITUDE-----
# -0.155250194816181
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 24-26 Baker Street
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# W1U 3BZ
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 24-26 Baker Street
# London W1U 3BZ
# United Kingdom
#
# -----PHONE-----
# +442074874688
#
# -----DISPLAY_PHONE-----
# +44 20 7487 4688
#
# -----DISTANCE-----
# 1446.0336151092515
# --------------------------------------END BUSINESS 48-------------------------------------
#
#
#
# ----------------------------------------49. MAMALAN----------------------------------------
#
# -----ID-----
# Gag-sVfJ3DpEiYvBvgm8Uw
#
# -----ALIAS-----
# mamalan-london-5
#
# -----NAME-----
# Mamalan
#
# -----IMAGE_URL-----
# https://s3-media4.fl.yelpcdn.com/bphoto/OvxVUiavE_N6bqL_qzVEug/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/mamalan-london-5?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 25
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----ALIAS-----
# bars
#
# -----TITLE-----
# Bars
#
# -----RATING-----
# 4.0
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.4624237690863
#
# -----LONGITUDE-----
# -0.111667388978524
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# £
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# Unit 18 Brixton Village
#
# -----ADDRESS2-----
# Coldharbour Lane
#
# -----ADDRESS3-----
# None
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# SW9 8PR
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# Unit 18 Brixton Village
# Coldharbour Lane
# London SW9 8PR
# United Kingdom
#
# -----PHONE-----
#
#
# -----DISPLAY_PHONE-----
#
#
# -----DISTANCE-----
# 5852.354882052575
# ----------------------------------------END BUSINESS 49---------------------------------------
#
#
#
# ----------------------------------------50. MURGER HAN----------------------------------------
#
# -----ID-----
# S3KrbezyEy4hR3K6JYMrJA
#
# -----ALIAS-----
# murger-han-london-3
#
# -----NAME-----
# Murger Han
#
# -----IMAGE_URL-----
# https://s3-media3.fl.yelpcdn.com/bphoto/zZ_2Ry6e9zo_CbQVhrL6OQ/o.jpg
#
# -----IS_CLOSED-----
# False
#
# -----URL-----
# https://www.yelp.com/biz/murger-han-london-3?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ
#
# -----REVIEW_COUNT-----
# 10
#
# -----CATEGORIES-----
#
# -----ALIAS-----
# chinese
#
# -----TITLE-----
# Chinese
#
# -----ALIAS-----
# cocktailbars
#
# -----TITLE-----
# Cocktail Bars
#
# -----RATING-----
# 4.5
#
# -----COORDINATES-----
#
# -----LATITUDE-----
# 51.50933
#
# -----LONGITUDE-----
# -0.13797
#
# -----TRANSACTIONS-----
#
# -----PRICE-----
# ££
#
# -----LOCATION-----
#
# -----ADDRESS1-----
# 8A Sackville street
#
# -----ADDRESS2-----
#
#
# -----ADDRESS3-----
#
#
# -----CITY-----
# London
#
# -----ZIP_CODE-----
# W1S 3DF
#
# -----COUNTRY-----
# GB
#
# -----STATE-----
# XGL
#
# -----DISPLAY_ADDRESS-----
# 8A Sackville street
# London W1S 3DF
# United Kingdom
#
# -----PHONE-----
# +442077340300
#
# -----DISPLAY_PHONE-----
# +44 20 7734 0300
#
# -----DISTANCE-----
# 407.97324803935334

# %% [markdown]
# Great, now are are getting somewhere. It is a good idea at this stage to store this information as a dataframe for processing further.
# ### Create a Pandas dataframe for contents of `businesses`
# * Check the number of records in the dataframe
# * Inspect the columns and head

# %%
# Code here 
values = []
cols = list(response['businesses'][0].keys())
for item in response['businesses']:
    values.append(list(item.values()))
cols, values[:5]
# Out:
# (['id',
#   'alias',
#   'name',
#   'image_url',
#   'is_closed',
#   'url',
#   'review_count',
#   'categories',
#   'rating',
#   'coordinates',
#   'transactions',
#   'price',
#   'location',
#   'phone',
#   'display_phone',
#   'distance'],
#  [['h2cCoDNQOPd51HFwvuAGNg',
#    'hakkasan-london-3',
#    'Hakkasan',
#    'https://s3-media2.fl.yelpcdn.com/bphoto/IcS9yzJnweDO4DsfJ94jAw/o.jpg',
#    False,
#    'https://www.yelp.com/biz/hakkasan-london-3?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    219,
#    [{'alias': 'cantonese', 'title': 'Cantonese'}],
#    4.0,
#    {'latitude': 51.5171482803943, 'longitude': -0.13180578932657},
#    [],
#    '££££',
#    {'address1': '8 Hanway Place',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 1HD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['8 Hanway Place', 'London W1T 1HD', 'United Kingdom']},
#    '+442079277000',
#    '+44 20 7927 7000',
#    558.9650039747677],
#   ['QE5aa5N-dbfvafLsjn7TVg',
#    'bamboo-flute-fitzrovia',
#    'Bamboo Flute',
#    'https://s3-media3.fl.yelpcdn.com/bphoto/kYQZjHmzt8zy1634OsAsxQ/o.jpg',
#    False,
#    'https://www.yelp.com/biz/bamboo-flute-fitzrovia?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    28,
#    [{'alias': 'chinese', 'title': 'Chinese'}],
#    4.5,
#    {'latitude': 51.5228746, 'longitude': -0.1418939},
#    [],
#    '£',
#    {'address1': '145 Cleveland Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Fitzrovia',
#     'zip_code': 'W1T 6QH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['145 Cleveland Street',
#      'Fitzrovia W1T 6QH',
#      'United Kingdom']},
#    '+442073872738',
#    '+44 20 7387 2738',
#    1189.5082547156321],
#   ['sYwBQ7mJYhB35nn-_SZstQ',
#    'yauatcha-london-7',
#    'Yauatcha',
#    'https://s3-media1.fl.yelpcdn.com/bphoto/G7Ydt9lmtWsUN1gRhlCRsw/o.jpg',
#    False,
#    'https://www.yelp.com/biz/yauatcha-london-7?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    460,
#    [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    4.0,
#    {'latitude': 51.5137076071076, 'longitude': -0.135128831605189},
#    [],
#    '£££',
#    {'address1': '15-17 Broadwick Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 0DL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['15-17 Broadwick Street',
#      'London W1F 0DL',
#      'United Kingdom']},
#    '+442074948888',
#    '+44 20 7494 8888',
#    112.59840998419494],
#   ['xYYh1dd95idvwCoGZWq58g',
#    'bao-soho-london',
#    'BAO - Soho',
#    'https://s3-media4.fl.yelpcdn.com/bphoto/L-08d4lsRSOe2HlIs1ZmfA/o.jpg',
#    False,
#    'https://www.yelp.com/biz/bao-soho-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    167,
#    [{'alias': 'taiwanese', 'title': 'Taiwanese'}],
#    4.0,
#    {'latitude': 51.5132221949841, 'longitude': -0.136528484994449},
#    [],
#    '££',
#    {'address1': '53 Lexington Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9AS',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['53 Lexington Street',
#      'London W1F 9AS',
#      'United Kingdom']},
#    '+442030192200',
#    '+44 20 3019 2200',
#    58.47355609756945],
#   ['pdFiFtol9YI__9ROOXUIYA',
#    'lanzhou-noodle-bar-london',
#    'Lanzhou Noodle Bar',
#    'https://s3-media4.fl.yelpcdn.com/bphoto/OMre4TNCrkDck3wqpUXbjQ/o.jpg',
#    False,
#    'https://www.yelp.com/biz/lanzhou-noodle-bar-london?adjust_creative=TKz2edtltxgYtPzgSrH9EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=TKz2edtltxgYtPzgSrH9EQ',
#    313,
#    [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    4.0,
#    {'latitude': 51.5116034713013, 'longitude': -0.127834377873126},
#    [],
#    '£',
#    {'address1': '33 Cranbourne Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 7AD',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['33 Cranbourne Street',
#      'London WC2H 7AD',
#      'United Kingdom']},
#    '+442074674546',
#    '+44 20 7467 4546',
#    578.4743547816091]])

# %%
import pandas as pd
businesses = pd.DataFrame(values)
businesses.columns = cols
businesses.head()
# Out:
#                        id                      alias                name  \
# 0  h2cCoDNQOPd51HFwvuAGNg          hakkasan-london-3            Hakkasan
# 1  QE5aa5N-dbfvafLsjn7TVg     bamboo-flute-fitzrovia        Bamboo Flute
# 2  sYwBQ7mJYhB35nn-_SZstQ          yauatcha-london-7            Yauatcha
# 3  xYYh1dd95idvwCoGZWq58g            bao-soho-london          BAO - Soho
# 4  pdFiFtol9YI__9ROOXUIYA  lanzhou-noodle-bar-london  Lanzhou Noodle Bar
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/IcS9yz...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/kYQZjH...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/G7Ydt9...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/L-08d4...      False
# 4  https://s3-media4.fl.yelpcdn.com/bphoto/OMre4T...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/hakkasan-london-3?adj...           219
# 1  https://www.yelp.com/biz/bamboo-flute-fitzrovi...            28
# 2  https://www.yelp.com/biz/yauatcha-london-7?adj...           460
# 3  https://www.yelp.com/biz/bao-soho-london?adjus...           167
# 4  https://www.yelp.com/biz/lanzhou-noodle-bar-lo...           313
#
#                                           categories  rating  \
# 0     [{'alias': 'cantonese', 'title': 'Cantonese'}]     4.0
# 1         [{'alias': 'chinese', 'title': 'Chinese'}]     4.5
# 2  [{'alias': 'dimsum', 'title': 'Dim Sum'}, {'al...     4.0
# 3     [{'alias': 'taiwanese', 'title': 'Taiwanese'}]     4.0
# 4  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     4.0
#
#                                          coordinates transactions price  \
# 0  {'latitude': 51.5171482803943, 'longitude': -0...           []  ££££
# 1  {'latitude': 51.5228746, 'longitude': -0.1418939}           []     £
# 2  {'latitude': 51.5137076071076, 'longitude': -0...           []   £££
# 3  {'latitude': 51.5132221949841, 'longitude': -0...           []    ££
# 4  {'latitude': 51.5116034713013, 'longitude': -0...           []     £
#
#                                             location          phone  \
# 0  {'address1': '8 Hanway Place', 'address2': '',...  +442079277000
# 1  {'address1': '145 Cleveland Street', 'address2...  +442073872738
# 2  {'address1': '15-17 Broadwick Street', 'addres...  +442074948888
# 3  {'address1': '53 Lexington Street', 'address2'...  +442030192200
# 4  {'address1': '33 Cranbourne Street', 'address2...  +442074674546
#
#       display_phone     distance
# 0  +44 20 7927 7000   558.965004
# 1  +44 20 7387 2738  1189.508255
# 2  +44 20 7494 8888   112.598410
# 3  +44 20 3019 2200    58.473556
# 4  +44 20 7467 4546   578.474355

# %%
businesses.shape
# Out:
# (50, 16)

# %% [markdown]
# This is fantastic. We have successfully learned a new API , made requests to it, recieved and studied the response and stored the results in a dataframe and can now enjoy all the goodness of Pandas. Thats quite a bit of data engineering.
#
# ### Visualize the location from search query
# The `region` key in the response carries the geographical information for the region searched.
# * Get the latitude / longitude information from `region`
# * Create a folium map with these coordinates.
# * Use a zoom start value = 13

# %%
import folium

region = response['region']['center']
loc = [region[coord] for coord in region.keys()][::-1]
london_map = folium.Map(location=loc, zoom_start=13)
london_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Expected Output:
# ![](london.png)

# %% [markdown]
# Nice. We can now extract the coordinate information for each business and plot it on this map.
#
# ### Get the business coordinates from dataframe for each business and plot on the map above

# %%
for coords in businesses['coordinates']:
    folium.Marker(location = [coords['latitude'], coords['longitude']]).add_to(london_map)

london_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Expected output:
# ![](markers.png)

# %% [markdown]
# Kool so we have everything in place but the visualization is still not very *Informative* so to speak. You can't tell which marker represents which business and also other information on business like rating, cost, links to user reviews etc. is still not visible. SO its geographical , but not exactly an Information System yet as you cant make any decisions on this information.  Here's as example of what it possible can look like
# ![](out.png)

# %%
businesses.iloc[0]
# Out:
# id                                          h2cCoDNQOPd51HFwvuAGNg
# alias                                            hakkasan-london-3
# name                                                      Hakkasan
# image_url        https://s3-media2.fl.yelpcdn.com/bphoto/IcS9yz...
# is_closed                                                    False
# url              https://www.yelp.com/biz/hakkasan-london-3?adj...
# review_count                                                   219
# categories          [{'alias': 'cantonese', 'title': 'Cantonese'}]
# rating                                                           4
# coordinates      {'latitude': 51.5171482803943, 'longitude': -0...
# transactions                                                    []
# price                                                         ££££
# location         {'address1': '8 Hanway Place', 'address2': '',...
# phone                                                +442079277000
# display_phone                                     +44 20 7927 7000
# distance                                                   558.965
# Name: 0, dtype: object

# %%
london_map = folium.Map(location=loc, zoom_start=13)
for i in range(len(businesses)):
    coords = [businesses.iloc[i]['coordinates']['latitude'], businesses.iloc[i]['coordinates']['longitude']]
    popups = [businesses.iloc[i]['name'], businesses.iloc[i]['image_url'], businesses.iloc[i]['price'], businesses.iloc[i]['url']]
    popups = "NAME: {} --- IMAGE URL: {} --- PRICE: {} --- URL: {}".format(*popups)
    folium.Marker(location = coords, popup=folium.Popup(popups, max_width=1000)).add_to(london_map)

london_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# For this you need to understand `folium.popup()` which let's you click on a marker to show a pop up window. This window acts more like an HTML page so you can easily format the information you present in the popup using following values:
# * The official business logo/image:  `image_url`
# * Name of the Business: `name`
# * Price (how expensive): `price`
# * Links to user reviews on Yelp: `url`
#
# Doing this in HTML is not required , so we recommend that you first try to put in basic information in the popups as just text. As a next stage , you can start changing into HTML code to make it visually more appealing.
#
# ### Attempt to recreate the interactive visualization shown above.
#
# Here's a good resource with code examples on [how to create folium popups](https://github.com/python-visualization/folium/blob/master/examples/Popups.ipynb)

# %%
# Code here

# %% [markdown]
# Wow . An Interactive Geographical information System backed by live data through API calling.
#
# <img src="star.jpg" width=300>
#
# ### More APIs to Checkout
#
# * Google Maps
# * Twitter
# * AWS
# * IBM's Watson
# * Yelp

# %% [markdown]
# ## Summary
#
# In this lab, we learned how to use the Yelp API with authentication, making calls, understanding the responses and creating interactive geographical visualizations in Folium. We encourage you to re-visit this lab again once you have studied some important machine learning algorithms to make predictions , find similarities, group/cluster businesses or classify them based on user criteria.
